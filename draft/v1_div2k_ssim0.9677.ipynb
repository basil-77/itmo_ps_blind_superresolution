# %%
import os

import numpy as np

import torch
import torchvision
from torchvision.io import read_image
from torchvision.transforms import v2

from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F

from piq import BRISQUELoss, TVLoss, brisque, ssim, psnr

import random

import cv2

import matplotlib.pyplot as plt

from utils import loss_history, plot_history

import json

# %matplotlib inline

# %%
path_hr_img = './data/div2k/DIV2K_train_HR'
path_lr_x2_img = './data/div2k/DIV2K_train_LR_unknown/X2'
images_lr = []
images_hr = []

for filename in os.listdir(path_lr_x2_img):
    img = read_image(os.path.join(path_lr_x2_img, filename))
    transform = torchvision.transforms.Compose([
        v2.ToPureTensor(),
        v2.ToDtype(torch.float)
    ])
    img = transform(img)/255.
    images_lr.append(img)
        
#for filename in os.listdir(path_hr_img):
#    img = read_image(os.path.join(path_hr_img, filename))
#    transform = torchvision.transforms.Compose([
#        v2.ToPureTensor(),
#        v2.ToDtype(torch.float)
#    ])
#    img = transform(img)/255.
#    images_hr.append(img)

# %%
i=0
for filename in os.listdir(path_hr_img):
    img = read_image(os.path.join(path_hr_img, filename))
    transform = torchvision.transforms.Compose([
        v2.ToPureTensor(),
        v2.ToDtype(torch.float)
    ])
    img = transform(img)/255.
    images_hr.append(img)
    i+=1
    if i>=6:
        break

# %%
images_lr_downscales = []
scale = 2

for image in images_lr:
    resizes = {
        'bilinear': torchvision.transforms.Resize((int(image.shape[1]/scale), int(image.shape[2]/scale)),
                                                 interpolation=torchvision.transforms.InterpolationMode.BILINEAR,
                                                 antialias=True),
        'nearest': torchvision.transforms.Resize((int(image.shape[1]/scale), int(image.shape[2]/scale)),
                                                 interpolation=torchvision.transforms.InterpolationMode.NEAREST,
                                                 antialias=True),
        'nearest_exact': torchvision.transforms.Resize((int(image.shape[1]/scale), int(image.shape[2]/scale)),
                                                 interpolation=torchvision.transforms.InterpolationMode.NEAREST_EXACT,
                                                 antialias=True),
        'bicubic': torchvision.transforms.Resize((int(image.shape[1]/scale), int(image.shape[2]/scale)),
                                                 interpolation=torchvision.transforms.InterpolationMode.BICUBIC,
                                                 antialias=True),  
    }
    resize_as = random.choice(list(resizes.values()))
    image_downscale = resize_as(image)
    images_lr_downscales.append(image_downscale)

# %%
plt.imshow(images_lr[5].permute(1,2,0))

# %%
class images_dataset(Dataset):
    def __init__(self, data_source, data_target):
        self.data_source = data_source
        self.data_target = data_target
        
    def __len__(self):
        return len(self.data_source)
    
    def __getitem__(self, index):
        data_source = self.data_source[index]
        data_target = self.data_target[index]
        return data_source, data_target

# %%
def collate_fn(batch):
    data_source = torch.LongTensor([item[0] for item in batch])
    data_target = torch.LongTensor([item[1] for item in batch])
    return data_source, data_target

# %%
ds_lr_downscaled = images_dataset(images_lr_downscales, images_lr)
ds_lr_downscaled_train = images_dataset(images_lr_downscales[4:5], images_lr[4:5])
ds_lr_downscaled_test = images_dataset(images_lr_downscales[:5], images_lr[:5])
#ds_lr_downscaled_train, ds_lr_downscaled_test = torch.utils.data.random_split(ds_lr_downscaled, [0.8, 0.2])

BATCH_SIZE = 1

dl_lrdown2lr_train = DataLoader(ds_lr_downscaled_train,
                               batch_size=BATCH_SIZE,
                               shuffle=True)
dl_lrdown2lr_test = DataLoader(ds_lr_downscaled_test,
                               batch_size=BATCH_SIZE,
                               shuffle=True)

dl_lrdown2lr = {'train': dl_lrdown2lr_train, 'test': dl_lrdown2lr_test}

# %%
class conv_block(nn.Module):
    def __init__(self, *args, **kwargs):
        super(conv_block, self).__init__()
        self.conv1 = nn.Conv2d(*args, **kwargs)
        self.bn = nn.BatchNorm2d(kwargs['out_channels'])
        self.activation = nn.GELU()
        
    def forward(self, x):
        x_input = x
        x = self.conv1(x_input)
        x = self.bn(x)
        x = self.activation(x)
        return x + x_input
        

class lrdown2lr(nn.Module):
    def __init__(self, scale=2, n_blocks=1, channels=64):
        super().__init__()
        
        self.n_blocks = n_blocks
        self.channels = channels
        
        self.upscale = nn.Upsample(scale_factor=2)
        
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=3, kernel_size=(3,3), stride=1, padding='same'),
            nn.Conv2d(in_channels=3, out_channels=3, kernel_size=(5,5), stride=1, padding='same')
        )
        self.conv_resc1 = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=(1,1), padding='same')
        
        self.conv_in = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=channels, kernel_size=3, padding='same'),
            nn.GELU()
        )
        self.conv_inner_blocks = nn.ModuleList(conv_block(in_channels=channels,
                                     out_channels=channels,
                                     kernel_size=3,
                                     padding='same') for n in range(n_blocks))
        
        self.conv_out = nn.Sequential(
            nn.Conv2d(in_channels=channels, out_channels=3, kernel_size=3, padding='same'),
            nn.GELU()
        )

    
    def forward(self, x):
        x = self.upscale(x)
        x = self.conv(x) + self.conv_resc1(x)
        x = self.conv_in(x)
        for conv_inner in self.conv_inner_blocks:
            x = conv_inner(x)
        x = self.conv_out(x)
        x = torch.clamp(x, min=0., max=1.)
       
        return x

# %%
class torch_trainer():
    
    def __init__(self, model, criterion, optimizer, epochs, dataloader, device='cuda'):
        self.model = model
        self.criterion = criterion
        self.optimizer = optimizer
        self.epochs = epochs
        self.dataloader = dataloader
        self.device = device
        self.history = loss_history()
        
    
        
    def train(self):

        self.history.clear()
        loss = 0
        val_loss = 0

        for epoch in range(self.epochs):

            epoch_loss = []
            epoch_val_loss = []
            items = len(self.dataloader['train'])

            self.model.train()
            item=1
            for batch in self.dataloader['train']:
                self.optimizer.zero_grad()
                data = batch[0].to(device)
                preds = self.model(data)
                del data
                target = batch[1].to(device)
                loss = self.criterion(preds, target)
                del target
                del preds
                loss.backward()
                epoch_loss.append(loss.numpy(force=True))
                self.optimizer.step()
                print (f'epoch {epoch+1}/{self.epochs}... {item}/{items}: train loss: {loss:.4f}, val_loss: {val_loss:.4f}', end='\r')
                item+=1

            items = len(self.dataloader['test'])
            self.model.eval()
            item=1
            with torch.no_grad():
                for batch in self.dataloader['test']:
                    data = batch[0].to(device)
                    preds = self.model(data)
                    del data
                    target = batch[1].to(device)
                    val_loss = self.criterion(preds, target)
                    del target
                    del preds
                    epoch_val_loss.append(val_loss.numpy(force=True))
                    print (f'epoch {epoch+1}/{self.epochs}... {item}/{items}: train loss: {loss:.4f}, val_loss: {val_loss:.4f}', end='\r')
                    item+=1

            loss = np.array(epoch_loss).mean()
            val_loss = np.array(epoch_val_loss).mean()

            self.history.loss.append(loss)
            self.history.val_loss.append(val_loss)

            print (f'epoch {epoch+1}/{self.epochs}; train loss: {loss:.4f}, val_loss: {val_loss:.4f}', end='\n')

        return self.history

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print (device)
# Out:
# cuda

# %%
model = lrdown2lr(channels=128).to(device)
print(model)
# Out:
# lrdown2lr(
#   (upscale): Upsample(scale_factor=2.0, mode='nearest')
#   (conv): Sequential(
#     (0): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): Conv2d(3, 3, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   )
#   (conv_resc1): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1), padding=same)
#   (conv_in): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): GELU(approximate='none')
#   )
#   (conv_inner_blocks): ModuleList(
#     (0): conv_block(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): GELU(approximate='none')
#     )
#   )
#   (conv_out): Sequential(
#     (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): GELU(approximate='none')
#   )
# )

# %%
def loss_tv(y_pred, y_true):
    loss = TVLoss()(y_pred)
    loss = 100/loss + 10*nn.SmoothL1Loss()(y_pred, y_true)
    return loss

# %%
torch.cuda.empty_cache()
criterion = loss_tv
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)
exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)
trainer = torch_trainer(model=model,
                       criterion=criterion,
                       optimizer=optimizer,
                       epochs=6000,
                       dataloader=dl_lrdown2lr)
history = trainer.train()
# Out:
# epoch 1/6000; train loss: 1.9868, val_loss: 14.557114.1292
# epoch 2/6000; train loss: 1.0905, val_loss: 7.8594 5.40281
# epoch 3/6000; train loss: 0.7422, val_loss: 5.1253 5.9974
# epoch 4/6000; train loss: 0.6997, val_loss: 3.6937 4.4152
# epoch 5/6000; train loss: 0.6555, val_loss: 2.8575 3.4796
# epoch 6/6000; train loss: 0.6260, val_loss: 2.3606 2.8870
# epoch 7/6000; train loss: 0.6033, val_loss: 2.1000 1.3002
# epoch 8/6000; train loss: 0.5962, val_loss: 1.9961 1.3261
# epoch 9/6000; train loss: 0.5920, val_loss: 1.9966 2.2000
# epoch 10/6000; train loss: 0.5857, val_loss: 2.0469 2.1919
# epoch 11/6000; train loss: 0.5753, val_loss: 2.1079 2.2727
# epoch 12/6000; train loss: 0.5646, val_loss: 2.1526 1.7764
# epoch 13/6000; train loss: 0.5534, val_loss: 2.1754 2.2068
# epoch 14/6000; train loss: 0.5435, val_loss: 2.1881 2.2535
# epoch 15/6000; train loss: 0.5404, val_loss: 2.1912 2.1565
# epoch 16/6000; train loss: 0.5288, val_loss: 2.1760 2.3171
# epoch 17/6000; train loss: 0.5224, val_loss: 2.1389 1.9856
# epoch 18/6000; train loss: 0.5190, val_loss: 2.0856 2.1853
# epoch 19/6000; train loss: 0.5173, val_loss: 2.0162 1.8949
# epoch 20/6000; train loss: 0.5094, val_loss: 1.9334 2.1099
# epoch 21/6000; train loss: 0.5040, val_loss: 1.8440 1.7172
# epoch 22/6000; train loss: 0.5010, val_loss: 1.7526 1.5713
# epoch 23/6000; train loss: 0.4947, val_loss: 1.6634 1.4803
# epoch 24/6000; train loss: 0.4892, val_loss: 1.5765 1.7009
# epoch 25/6000; train loss: 0.4864, val_loss: 1.4930 1.3302
# epoch 26/6000; train loss: 0.4815, val_loss: 1.4177 1.1693
# epoch 27/6000; train loss: 0.4773, val_loss: 1.3536 1.0735
# epoch 28/6000; train loss: 0.4740, val_loss: 1.2996 1.3800
# epoch 29/6000; train loss: 0.4704, val_loss: 1.2524 0.9106
# epoch 30/6000; train loss: 0.4665, val_loss: 1.2090 0.8347
# epoch 31/6000; train loss: 0.4628, val_loss: 1.1721 1.4535
# epoch 32/6000; train loss: 0.4585, val_loss: 1.1462 1.2740
# epoch 33/6000; train loss: 0.4535, val_loss: 1.1338 1.0514
# epoch 34/6000; train loss: 0.4482, val_loss: 1.1353 1.2689
# epoch 35/6000; train loss: 0.4408, val_loss: 1.1757 1.0834
# epoch 36/6000; train loss: 0.4299, val_loss: 1.2209 0.7802
# epoch 37/6000; train loss: 0.4340, val_loss: 1.1311 0.6910
# epoch 38/6000; train loss: 0.4311, val_loss: 1.0871 1.1615
# epoch 39/6000; train loss: 0.4294, val_loss: 1.0665 1.3626
# epoch 40/6000; train loss: 0.4220, val_loss: 1.1000 1.1592
# epoch 41/6000; train loss: 0.4162, val_loss: 1.1364 1.1426
# epoch 42/6000; train loss: 0.4200, val_loss: 1.0295 1.0935
# epoch 43/6000; train loss: 0.4089, val_loss: 1.0050 1.2509
# epoch 44/6000; train loss: 0.4091, val_loss: 1.0852 1.1837
# epoch 45/6000; train loss: 0.3980, val_loss: 1.3563 1.8516
# epoch 46/6000; train loss: 0.3966, val_loss: 1.2936 1.2209
# epoch 47/6000; train loss: 0.3830, val_loss: 1.1196 1.4848
# epoch 48/6000; train loss: 0.3910, val_loss: 1.1869 1.6416
# epoch 49/6000; train loss: 0.3857, val_loss: 1.3690 1.3946
# epoch 50/6000; train loss: 0.3834, val_loss: 1.2890 1.3131
# epoch 51/6000; train loss: 0.3750, val_loss: 1.1300 1.6523
# epoch 52/6000; train loss: 0.3767, val_loss: 1.1588 1.1462
# epoch 53/6000; train loss: 0.3751, val_loss: 1.1608 1.1696
# epoch 54/6000; train loss: 0.3693, val_loss: 1.0647 1.2275
# epoch 55/6000; train loss: 0.3705, val_loss: 1.0033 1.4893
# epoch 56/6000; train loss: 0.3656, val_loss: 0.9580 1.0723
# epoch 57/6000; train loss: 0.3685, val_loss: 0.8324 1.1993
# epoch 58/6000; train loss: 0.3632, val_loss: 0.8078 0.8298
# epoch 59/6000; train loss: 0.3626, val_loss: 0.8059 0.6655
# epoch 60/6000; train loss: 0.3612, val_loss: 0.7370 0.5997
# epoch 61/6000; train loss: 0.3576, val_loss: 0.7209 0.6559
# epoch 62/6000; train loss: 0.3552, val_loss: 0.7686 0.7708
# epoch 63/6000; train loss: 0.3525, val_loss: 0.7739 0.7864
# epoch 64/6000; train loss: 0.3450, val_loss: 0.8300 0.7568
# epoch 65/6000; train loss: 0.3426, val_loss: 0.8443 0.8003
# epoch 66/6000; train loss: 0.3436, val_loss: 0.6401 0.5853
# epoch 67/6000; train loss: 0.3414, val_loss: 0.5671 0.4913
# epoch 68/6000; train loss: 0.3464, val_loss: 0.5882 0.6257
# epoch 69/6000; train loss: 0.3452, val_loss: 0.6280 0.5615
# epoch 70/6000; train loss: 0.3421, val_loss: 0.6951 0.5123
# epoch 71/6000; train loss: 0.3353, val_loss: 0.7390 1.0632
# epoch 72/6000; train loss: 0.3454, val_loss: 0.6183 0.4262
# epoch 73/6000; train loss: 0.3379, val_loss: 0.5803 0.5017
# epoch 74/6000; train loss: 0.3412, val_loss: 0.6048 0.6684
# epoch 75/6000; train loss: 0.3340, val_loss: 0.6707 0.6033
# epoch 76/6000; train loss: 0.3425, val_loss: 0.6286 0.6451
# epoch 77/6000; train loss: 0.3313, val_loss: 0.6143 0.3932
# epoch 78/6000; train loss: 0.3374, val_loss: 0.6142 0.6390
# epoch 79/6000; train loss: 0.3356, val_loss: 0.6111 0.8122
# epoch 80/6000; train loss: 0.3323, val_loss: 0.5969 0.6106
# epoch 81/6000; train loss: 0.3329, val_loss: 0.5805 0.4916
# epoch 82/6000; train loss: 0.3330, val_loss: 0.5712 0.6852
# epoch 83/6000; train loss: 0.3331, val_loss: 0.5728 0.4705
# epoch 84/6000; train loss: 0.3309, val_loss: 0.5923 0.3881
# epoch 85/6000; train loss: 0.3320, val_loss: 0.6170 0.5314
# epoch 86/6000; train loss: 0.3302, val_loss: 0.6258 0.7095
# epoch 87/6000; train loss: 0.3317, val_loss: 0.6380 0.7292
# epoch 88/6000; train loss: 0.3297, val_loss: 0.6176 0.7982
# epoch 89/6000; train loss: 0.3304, val_loss: 0.5936 0.7591
# epoch 90/6000; train loss: 0.3293, val_loss: 0.5991 0.4054
# epoch 91/6000; train loss: 0.3301, val_loss: 0.6153 0.7934
# epoch 92/6000; train loss: 0.3286, val_loss: 0.6304 0.7446
# epoch 93/6000; train loss: 0.3296, val_loss: 0.6555 0.6631
# epoch 94/6000; train loss: 0.3286, val_loss: 0.6565 0.5703
# epoch 95/6000; train loss: 0.3288, val_loss: 0.6323 0.7286
# epoch 96/6000; train loss: 0.3285, val_loss: 0.6195 0.8146
# epoch 97/6000; train loss: 0.3283, val_loss: 0.6153 0.8066
# epoch 98/6000; train loss: 0.3281, val_loss: 0.6001 0.3980
# epoch 99/6000; train loss: 0.3282, val_loss: 0.5944 0.3932
# epoch 100/6000; train loss: 0.3279, val_loss: 0.5984 0.6056
# epoch 101/6000; train loss: 0.3277, val_loss: 0.6049 0.7049
# epoch 102/6000; train loss: 0.3279, val_loss: 0.6126 0.7086
# epoch 103/6000; train loss: 0.3273, val_loss: 0.6047 0.3947
# epoch 104/6000; train loss: 0.3277, val_loss: 0.5881 0.4858
# epoch 105/6000; train loss: 0.3272, val_loss: 0.5771 0.7553
# epoch 106/6000; train loss: 0.3274, val_loss: 0.5680 0.5792
# epoch 107/6000; train loss: 0.3271, val_loss: 0.5672 0.4582
# epoch 108/6000; train loss: 0.3272, val_loss: 0.5782 0.5918
# epoch 109/6000; train loss: 0.3270, val_loss: 0.5786 0.6877
# epoch 110/6000; train loss: 0.3270, val_loss: 0.5762 0.7604
# epoch 111/6000; train loss: 0.3268, val_loss: 0.5783 0.4678
# epoch 112/6000; train loss: 0.3269, val_loss: 0.5702 0.4597
# epoch 113/6000; train loss: 0.3268, val_loss: 0.5606 0.5811
# epoch 114/6000; train loss: 0.3266, val_loss: 0.5573 0.7268
# epoch 115/6000; train loss: 0.3267, val_loss: 0.5560 0.6756
# epoch 116/6000; train loss: 0.3265, val_loss: 0.5630 0.3606
# epoch 117/6000; train loss: 0.3265, val_loss: 0.5709 0.5963
# epoch 118/6000; train loss: 0.3264, val_loss: 0.5698 0.3613
# epoch 119/6000; train loss: 0.3264, val_loss: 0.5658 0.7433
# epoch 120/6000; train loss: 0.3263, val_loss: 0.5580 0.7290
# epoch 121/6000; train loss: 0.3262, val_loss: 0.5552 0.5799
# epoch 122/6000; train loss: 0.3262, val_loss: 0.5573 0.6822
# epoch 123/6000; train loss: 0.3261, val_loss: 0.5581 0.3541
# epoch 124/6000; train loss: 0.3261, val_loss: 0.5636 0.4456
# epoch 125/6000; train loss: 0.3260, val_loss: 0.5664 0.4472
# epoch 126/6000; train loss: 0.3259, val_loss: 0.5645 0.5933
# epoch 127/6000; train loss: 0.3258, val_loss: 0.5629 0.5901
# epoch 128/6000; train loss: 0.3258, val_loss: 0.5577 0.3502
# epoch 129/6000; train loss: 0.3257, val_loss: 0.5599 0.6887
# epoch 130/6000; train loss: 0.3256, val_loss: 0.5654 0.6944
# epoch 131/6000; train loss: 0.3255, val_loss: 0.5733 0.3581
# epoch 132/6000; train loss: 0.3255, val_loss: 0.5768 0.3587
# epoch 133/6000; train loss: 0.3254, val_loss: 0.5822 0.3661
# epoch 134/6000; train loss: 0.3260, val_loss: 0.5691 0.7452
# epoch 135/6000; train loss: 0.3272, val_loss: 0.6033 0.8015
# epoch 136/6000; train loss: 0.3289, val_loss: 0.5706 0.6164
# epoch 137/6000; train loss: 0.3270, val_loss: 0.6088 0.8169
# epoch 138/6000; train loss: 0.3258, val_loss: 0.6092 0.8174
# epoch 139/6000; train loss: 0.3255, val_loss: 0.5736 0.6244
# epoch 140/6000; train loss: 0.3269, val_loss: 0.6138 0.7269
# epoch 141/6000; train loss: 0.3268, val_loss: 0.5683 0.4387
# epoch 142/6000; train loss: 0.3250, val_loss: 0.5574 0.6058
# epoch 143/6000; train loss: 0.3249, val_loss: 0.5558 0.3520
# epoch 144/6000; train loss: 0.3250, val_loss: 0.5297 0.5676
# epoch 145/6000; train loss: 0.3251, val_loss: 0.5169 0.4095
# epoch 146/6000; train loss: 0.3281, val_loss: 0.5129 0.6346
# epoch 147/6000; train loss: 0.3263, val_loss: 0.5225 0.6681
# epoch 148/6000; train loss: 0.3237, val_loss: 0.5495 0.5693
# epoch 149/6000; train loss: 0.3254, val_loss: 0.5815 0.6047
# epoch 150/6000; train loss: 0.3241, val_loss: 0.6124 0.6307
# epoch 151/6000; train loss: 0.3231, val_loss: 0.5873 0.3601
# epoch 152/6000; train loss: 0.3239, val_loss: 0.5874 0.4587
# epoch 153/6000; train loss: 0.3228, val_loss: 0.5740 0.6894
# epoch 154/6000; train loss: 0.3226, val_loss: 0.5637 0.7405
# epoch 155/6000; train loss: 0.3228, val_loss: 0.6050 0.4721
# epoch 156/6000; train loss: 0.3214, val_loss: 0.6168 0.7445
# epoch 157/6000; train loss: 0.3206, val_loss: 0.6158 0.8373
# epoch 158/6000; train loss: 0.3208, val_loss: 0.6254 0.3806
# epoch 159/6000; train loss: 0.3206, val_loss: 0.5764 0.3488
# epoch 160/6000; train loss: 0.3211, val_loss: 0.6060 0.6869
# epoch 161/6000; train loss: 0.3214, val_loss: 0.5831 0.3534
# epoch 162/6000; train loss: 0.3191, val_loss: 0.6528 0.9114
# epoch 163/6000; train loss: 0.3178, val_loss: 0.6343 0.7326
# epoch 164/6000; train loss: 0.3170, val_loss: 0.6022 0.6457
# epoch 165/6000; train loss: 0.3162, val_loss: 0.6357 0.6912
# epoch 166/6000; train loss: 0.3164, val_loss: 0.5520 0.3496
# epoch 167/6000; train loss: 0.3157, val_loss: 0.6181 0.6594
# epoch 168/6000; train loss: 0.3142, val_loss: 0.5980 0.6791
# epoch 169/6000; train loss: 0.3125, val_loss: 0.5916 0.4810
# epoch 170/6000; train loss: 0.3107, val_loss: 0.5564 0.3591
# epoch 171/6000; train loss: 0.3093, val_loss: 0.5268 0.3522
# epoch 172/6000; train loss: 0.3085, val_loss: 0.5847 0.6322
# epoch 173/6000; train loss: 0.3076, val_loss: 0.5840 0.7838
# epoch 174/6000; train loss: 0.3076, val_loss: 0.6596 0.7277
# epoch 175/6000; train loss: 0.3087, val_loss: 0.5949 0.5143
# epoch 176/6000; train loss: 0.3072, val_loss: 0.6240 0.3906
# epoch 177/6000; train loss: 0.3039, val_loss: 0.6373 0.6546
# epoch 178/6000; train loss: 0.2974, val_loss: 0.6422 0.5663
# epoch 179/6000; train loss: 0.2935, val_loss: 0.6357 0.6827
# epoch 180/6000; train loss: 0.2927, val_loss: 0.6604 0.6001
# epoch 181/6000; train loss: 0.2923, val_loss: 0.6787 0.5928
# epoch 182/6000; train loss: 0.2887, val_loss: 0.6780 0.6850
# epoch 183/6000; train loss: 0.2837, val_loss: 0.6674 0.9334
# epoch 184/6000; train loss: 0.2809, val_loss: 0.6046 0.5408
# epoch 185/6000; train loss: 0.2798, val_loss: 0.6484 0.6027
# epoch 186/6000; train loss: 0.2776, val_loss: 0.6219 0.6272
# epoch 187/6000; train loss: 0.2747, val_loss: 0.6074 0.8859
# epoch 188/6000; train loss: 0.2735, val_loss: 0.6170 0.4492
# epoch 189/6000; train loss: 0.2725, val_loss: 0.5679 0.5342
# epoch 190/6000; train loss: 0.2703, val_loss: 0.5438 0.5126
# epoch 191/6000; train loss: 0.2684, val_loss: 0.5291 0.4879
# epoch 192/6000; train loss: 0.2682, val_loss: 0.5102 0.4135
# epoch 193/6000; train loss: 0.2674, val_loss: 0.5073 0.4064
# epoch 194/6000; train loss: 0.2664, val_loss: 0.5210 0.7567
# epoch 195/6000; train loss: 0.2667, val_loss: 0.5374 0.4657
# epoch 196/6000; train loss: 0.2665, val_loss: 0.5632 0.4472
# epoch 197/6000; train loss: 0.2660, val_loss: 0.5630 0.8353
# epoch 198/6000; train loss: 0.2663, val_loss: 0.5286 0.4448
# epoch 199/6000; train loss: 0.2663, val_loss: 0.4990 0.4339
# epoch 200/6000; train loss: 0.2659, val_loss: 0.5065 0.4090
# epoch 201/6000; train loss: 0.2661, val_loss: 0.5090 0.5007
# epoch 202/6000; train loss: 0.2661, val_loss: 0.4854 0.4301
# epoch 203/6000; train loss: 0.2658, val_loss: 0.4713 0.3798
# epoch 204/6000; train loss: 0.2658, val_loss: 0.4660 0.6733
# epoch 205/6000; train loss: 0.2659, val_loss: 0.4588 0.3620
# epoch 206/6000; train loss: 0.2656, val_loss: 0.4552 0.3527
# epoch 207/6000; train loss: 0.2655, val_loss: 0.4522 0.6487
# epoch 208/6000; train loss: 0.2656, val_loss: 0.4517 0.4353
# epoch 209/6000; train loss: 0.2654, val_loss: 0.4408 0.4001
# epoch 210/6000; train loss: 0.2652, val_loss: 0.4387 0.3943
# epoch 211/6000; train loss: 0.2653, val_loss: 0.4361 0.6174
# epoch 212/6000; train loss: 0.2653, val_loss: 0.4325 0.6070
# epoch 213/6000; train loss: 0.2653, val_loss: 0.4269 0.4102
# epoch 214/6000; train loss: 0.2655, val_loss: 0.4260 0.4217
# epoch 215/6000; train loss: 0.2657, val_loss: 0.4253 0.5977
# epoch 216/6000; train loss: 0.2662, val_loss: 0.4340 0.3761
# epoch 217/6000; train loss: 0.2668, val_loss: 0.4287 0.3159
# epoch 218/6000; train loss: 0.2678, val_loss: 0.4378 0.4589
# epoch 219/6000; train loss: 0.2683, val_loss: 0.4304 0.6089
# epoch 220/6000; train loss: 0.2687, val_loss: 0.4283 0.5983
# epoch 221/6000; train loss: 0.2681, val_loss: 0.4151 0.5811
# epoch 222/6000; train loss: 0.2671, val_loss: 0.4126 0.2842
# epoch 223/6000; train loss: 0.2656, val_loss: 0.4050 0.5609
# epoch 224/6000; train loss: 0.2647, val_loss: 0.4020 0.4047
# epoch 225/6000; train loss: 0.2645, val_loss: 0.4024 0.2784
# epoch 226/6000; train loss: 0.2649, val_loss: 0.4026 0.4058
# epoch 227/6000; train loss: 0.2655, val_loss: 0.4110 0.4304
# epoch 228/6000; train loss: 0.2658, val_loss: 0.3956 0.5456
# epoch 229/6000; train loss: 0.2656, val_loss: 0.4026 0.5587
# epoch 230/6000; train loss: 0.2650, val_loss: 0.3961 0.5466
# epoch 231/6000; train loss: 0.2644, val_loss: 0.3904 0.4107
# epoch 232/6000; train loss: 0.2642, val_loss: 0.3877 0.3956
# epoch 233/6000; train loss: 0.2644, val_loss: 0.3854 0.3932
# epoch 234/6000; train loss: 0.2647, val_loss: 0.3914 0.3997
# epoch 235/6000; train loss: 0.2649, val_loss: 0.3826 0.3912
# epoch 236/6000; train loss: 0.2648, val_loss: 0.3880 0.4082
# epoch 237/6000; train loss: 0.2645, val_loss: 0.3874 0.5308
# epoch 238/6000; train loss: 0.2642, val_loss: 0.3879 0.3307
# epoch 239/6000; train loss: 0.2641, val_loss: 0.3852 0.4051
# epoch 240/6000; train loss: 0.2641, val_loss: 0.3834 0.5240
# epoch 241/6000; train loss: 0.2642, val_loss: 0.3897 0.5364
# epoch 242/6000; train loss: 0.2643, val_loss: 0.3820 0.3251
# epoch 243/6000; train loss: 0.2644, val_loss: 0.3865 0.2724
# epoch 244/6000; train loss: 0.2643, val_loss: 0.3837 0.3935
# epoch 245/6000; train loss: 0.2642, val_loss: 0.3890 0.2722
# epoch 246/6000; train loss: 0.2640, val_loss: 0.3837 0.3929
# epoch 247/6000; train loss: 0.2639, val_loss: 0.3841 0.3277
# epoch 248/6000; train loss: 0.2639, val_loss: 0.3865 0.2713
# epoch 249/6000; train loss: 0.2639, val_loss: 0.3828 0.3264
# epoch 250/6000; train loss: 0.2640, val_loss: 0.3839 0.2716
# epoch 251/6000; train loss: 0.2640, val_loss: 0.3804 0.3988
# epoch 252/6000; train loss: 0.2640, val_loss: 0.3856 0.4013
# epoch 253/6000; train loss: 0.2641, val_loss: 0.3799 0.3237
# epoch 254/6000; train loss: 0.2640, val_loss: 0.3831 0.3902
# epoch 255/6000; train loss: 0.2640, val_loss: 0.3795 0.3971
# epoch 256/6000; train loss: 0.2639, val_loss: 0.3826 0.2704
# epoch 257/6000; train loss: 0.2639, val_loss: 0.3779 0.3224
# epoch 258/6000; train loss: 0.2638, val_loss: 0.3794 0.3870
# epoch 259/6000; train loss: 0.2638, val_loss: 0.3777 0.5181
# epoch 260/6000; train loss: 0.2638, val_loss: 0.3782 0.3936
# epoch 261/6000; train loss: 0.2637, val_loss: 0.3763 0.3213
# epoch 262/6000; train loss: 0.2637, val_loss: 0.3770 0.3854
# epoch 263/6000; train loss: 0.2637, val_loss: 0.3763 0.3214
# epoch 264/6000; train loss: 0.2637, val_loss: 0.3753 0.3205
# epoch 265/6000; train loss: 0.2637, val_loss: 0.3745 0.2666
# epoch 266/6000; train loss: 0.2637, val_loss: 0.3741 0.2663
# epoch 267/6000; train loss: 0.2637, val_loss: 0.3740 0.2664
# epoch 268/6000; train loss: 0.2637, val_loss: 0.3727 0.2657
# epoch 269/6000; train loss: 0.2636, val_loss: 0.3731 0.5120
# epoch 270/6000; train loss: 0.2636, val_loss: 0.3724 0.5103
# epoch 271/6000; train loss: 0.2636, val_loss: 0.3730 0.3863
# epoch 272/6000; train loss: 0.2637, val_loss: 0.3712 0.5085
# epoch 273/6000; train loss: 0.2637, val_loss: 0.3728 0.2665
# epoch 274/6000; train loss: 0.2637, val_loss: 0.3705 0.2644
# epoch 275/6000; train loss: 0.2638, val_loss: 0.3734 0.3849
# epoch 276/6000; train loss: 0.2640, val_loss: 0.3698 0.3806
# epoch 277/6000; train loss: 0.2644, val_loss: 0.3760 0.5191
# epoch 278/6000; train loss: 0.2652, val_loss: 0.3711 0.2656
# epoch 279/6000; train loss: 0.2667, val_loss: 0.3819 0.2775
# epoch 280/6000; train loss: 0.2691, val_loss: 0.3772 0.3862
# epoch 281/6000; train loss: 0.2727, val_loss: 0.3893 0.3866
# epoch 282/6000; train loss: 0.2754, val_loss: 0.3768 0.3182
# epoch 283/6000; train loss: 0.2721, val_loss: 0.3777 0.3834
# epoch 284/6000; train loss: 0.2675, val_loss: 0.3686 0.2649
# epoch 285/6000; train loss: 0.2643, val_loss: 0.3728 0.3209
# epoch 286/6000; train loss: 0.2638, val_loss: 0.3786 0.3868
# epoch 287/6000; train loss: 0.2657, val_loss: 0.3755 0.3870
# epoch 288/6000; train loss: 0.2683, val_loss: 0.3772 0.3846
# epoch 289/6000; train loss: 0.2687, val_loss: 0.3696 0.3152
# epoch 290/6000; train loss: 0.2672, val_loss: 0.3730 0.3231
# epoch 291/6000; train loss: 0.2650, val_loss: 0.3681 0.3129
# epoch 292/6000; train loss: 0.2639, val_loss: 0.3699 0.5074
# epoch 293/6000; train loss: 0.2641, val_loss: 0.3732 0.3830
# epoch 294/6000; train loss: 0.2650, val_loss: 0.3710 0.3826
# epoch 295/6000; train loss: 0.2659, val_loss: 0.3789 0.3837
# epoch 296/6000; train loss: 0.2656, val_loss: 0.3710 0.3119
# epoch 297/6000; train loss: 0.2646, val_loss: 0.3719 0.3848
# epoch 298/6000; train loss: 0.2636, val_loss: 0.3697 0.5069
# epoch 299/6000; train loss: 0.2635, val_loss: 0.3694 0.3808
# epoch 300/6000; train loss: 0.2643, val_loss: 0.3769 0.2704
# epoch 301/6000; train loss: 0.2647, val_loss: 0.3744 0.2637
# epoch 302/6000; train loss: 0.2646, val_loss: 0.3785 0.3909
# epoch 303/6000; train loss: 0.2640, val_loss: 0.3726 0.2648
# epoch 304/6000; train loss: 0.2636, val_loss: 0.3713 0.3821
# epoch 305/6000; train loss: 0.2635, val_loss: 0.3720 0.3814
# epoch 306/6000; train loss: 0.2637, val_loss: 0.3734 0.3127
# epoch 307/6000; train loss: 0.2639, val_loss: 0.3767 0.5202
# epoch 308/6000; train loss: 0.2640, val_loss: 0.3724 0.5112
# epoch 309/6000; train loss: 0.2639, val_loss: 0.3743 0.3853
# epoch 310/6000; train loss: 0.2636, val_loss: 0.3736 0.3866
# epoch 311/6000; train loss: 0.2633, val_loss: 0.3731 0.3878
# epoch 312/6000; train loss: 0.2633, val_loss: 0.3742 0.5144
# epoch 313/6000; train loss: 0.2635, val_loss: 0.3716 0.3864
# epoch 314/6000; train loss: 0.2636, val_loss: 0.3722 0.2664
# epoch 315/6000; train loss: 0.2636, val_loss: 0.3707 0.3141
# epoch 316/6000; train loss: 0.2635, val_loss: 0.3724 0.3861
# epoch 317/6000; train loss: 0.2634, val_loss: 0.3732 0.3135
# epoch 318/6000; train loss: 0.2633, val_loss: 0.3723 0.5099
# epoch 319/6000; train loss: 0.2633, val_loss: 0.3720 0.2648
# epoch 320/6000; train loss: 0.2633, val_loss: 0.3711 0.3860
# epoch 321/6000; train loss: 0.2634, val_loss: 0.3719 0.2648
# epoch 322/6000; train loss: 0.2634, val_loss: 0.3733 0.3892
# epoch 323/6000; train loss: 0.2634, val_loss: 0.3720 0.5095
# epoch 324/6000; train loss: 0.2633, val_loss: 0.3712 0.3125
# epoch 325/6000; train loss: 0.2633, val_loss: 0.3715 0.3136
# epoch 326/6000; train loss: 0.2632, val_loss: 0.3728 0.3125
# epoch 327/6000; train loss: 0.2632, val_loss: 0.3741 0.5130
# epoch 328/6000; train loss: 0.2632, val_loss: 0.3729 0.3128
# epoch 329/6000; train loss: 0.2632, val_loss: 0.3725 0.2635
# epoch 330/6000; train loss: 0.2632, val_loss: 0.3726 0.3877
# epoch 331/6000; train loss: 0.2632, val_loss: 0.3743 0.2634
# epoch 332/6000; train loss: 0.2632, val_loss: 0.3739 0.5128
# epoch 333/6000; train loss: 0.2632, val_loss: 0.3734 0.3119
# epoch 334/6000; train loss: 0.2632, val_loss: 0.3725 0.3881
# epoch 335/6000; train loss: 0.2632, val_loss: 0.3745 0.3912
# epoch 336/6000; train loss: 0.2632, val_loss: 0.3748 0.3922
# epoch 337/6000; train loss: 0.2631, val_loss: 0.3753 0.3125
# epoch 338/6000; train loss: 0.2631, val_loss: 0.3737 0.3907
# epoch 339/6000; train loss: 0.2631, val_loss: 0.3745 0.3122
# epoch 340/6000; train loss: 0.2631, val_loss: 0.3754 0.3936
# epoch 341/6000; train loss: 0.2631, val_loss: 0.3760 0.3946
# epoch 342/6000; train loss: 0.2631, val_loss: 0.3756 0.3928
# epoch 343/6000; train loss: 0.2631, val_loss: 0.3752 0.2633
# epoch 344/6000; train loss: 0.2631, val_loss: 0.3763 0.3951
# epoch 345/6000; train loss: 0.2631, val_loss: 0.3771 0.3126
# epoch 346/6000; train loss: 0.2630, val_loss: 0.3773 0.3968
# epoch 347/6000; train loss: 0.2630, val_loss: 0.3763 0.2633
# epoch 348/6000; train loss: 0.2630, val_loss: 0.3771 0.3965
# epoch 349/6000; train loss: 0.2630, val_loss: 0.3774 0.3969
# epoch 350/6000; train loss: 0.2630, val_loss: 0.3789 0.5217
# epoch 351/6000; train loss: 0.2630, val_loss: 0.3771 0.3127
# epoch 352/6000; train loss: 0.2631, val_loss: 0.3790 0.2634
# epoch 353/6000; train loss: 0.2631, val_loss: 0.3771 0.3954
# epoch 354/6000; train loss: 0.2631, val_loss: 0.3814 0.4029
# epoch 355/6000; train loss: 0.2632, val_loss: 0.3774 0.3965
# epoch 356/6000; train loss: 0.2634, val_loss: 0.3827 0.4011
# epoch 357/6000; train loss: 0.2637, val_loss: 0.3769 0.2646
# epoch 358/6000; train loss: 0.2642, val_loss: 0.3892 0.3180
# epoch 359/6000; train loss: 0.2651, val_loss: 0.3798 0.5240
# epoch 360/6000; train loss: 0.2666, val_loss: 0.3969 0.4102
# epoch 361/6000; train loss: 0.2691, val_loss: 0.3845 0.3259
# epoch 362/6000; train loss: 0.2718, val_loss: 0.4070 0.4281
# epoch 363/6000; train loss: 0.2733, val_loss: 0.3917 0.4046
# epoch 364/6000; train loss: 0.2722, val_loss: 0.3846 0.3179
# epoch 365/6000; train loss: 0.2681, val_loss: 0.3739 0.3887
# epoch 366/6000; train loss: 0.2643, val_loss: 0.3769 0.5168
# epoch 367/6000; train loss: 0.2629, val_loss: 0.3823 0.3163
# epoch 368/6000; train loss: 0.2638, val_loss: 0.3783 0.3928
# epoch 369/6000; train loss: 0.2658, val_loss: 0.3854 0.3188
# epoch 370/6000; train loss: 0.2676, val_loss: 0.3774 0.3894
# epoch 371/6000; train loss: 0.2676, val_loss: 0.3813 0.3146
# epoch 372/6000; train loss: 0.2662, val_loss: 0.3781 0.3913
# epoch 373/6000; train loss: 0.2640, val_loss: 0.3757 0.3953
# epoch 374/6000; train loss: 0.2629, val_loss: 0.3761 0.3125
# epoch 375/6000; train loss: 0.2633, val_loss: 0.3791 0.5214
# epoch 376/6000; train loss: 0.2644, val_loss: 0.3892 0.4138
# epoch 377/6000; train loss: 0.2653, val_loss: 0.3829 0.5280
# epoch 378/6000; train loss: 0.2651, val_loss: 0.3840 0.2636
# epoch 379/6000; train loss: 0.2642, val_loss: 0.3790 0.3963
# epoch 380/6000; train loss: 0.2632, val_loss: 0.3811 0.3997
# epoch 381/6000; train loss: 0.2628, val_loss: 0.3843 0.4081
# epoch 382/6000; train loss: 0.2632, val_loss: 0.3840 0.4028
# epoch 383/6000; train loss: 0.2638, val_loss: 0.3842 0.3141
# epoch 384/6000; train loss: 0.2641, val_loss: 0.3823 0.2680
# epoch 385/6000; train loss: 0.2638, val_loss: 0.3870 0.4122
# epoch 386/6000; train loss: 0.2633, val_loss: 0.3844 0.2651
# epoch 387/6000; train loss: 0.2629, val_loss: 0.3822 0.4034
# epoch 388/6000; train loss: 0.2628, val_loss: 0.3826 0.5259
# epoch 389/6000; train loss: 0.2630, val_loss: 0.3831 0.4021
# epoch 390/6000; train loss: 0.2633, val_loss: 0.3864 0.4117
# epoch 391/6000; train loss: 0.2634, val_loss: 0.3839 0.3173
# epoch 392/6000; train loss: 0.2633, val_loss: 0.3830 0.3139
# epoch 393/6000; train loss: 0.2630, val_loss: 0.3811 0.2648
# epoch 394/6000; train loss: 0.2628, val_loss: 0.3839 0.2639
# epoch 395/6000; train loss: 0.2627, val_loss: 0.3849 0.5298
# epoch 396/6000; train loss: 0.2628, val_loss: 0.3820 0.3157
# epoch 397/6000; train loss: 0.2629, val_loss: 0.3836 0.4076
# epoch 398/6000; train loss: 0.2630, val_loss: 0.3825 0.5250
# epoch 399/6000; train loss: 0.2630, val_loss: 0.3861 0.3148
# epoch 400/6000; train loss: 0.2630, val_loss: 0.3830 0.2644
# epoch 401/6000; train loss: 0.2628, val_loss: 0.3835 0.3139
# epoch 402/6000; train loss: 0.2627, val_loss: 0.3829 0.2634
# epoch 403/6000; train loss: 0.2627, val_loss: 0.3849 0.5297
# epoch 404/6000; train loss: 0.2626, val_loss: 0.3869 0.5336
# epoch 405/6000; train loss: 0.2627, val_loss: 0.3863 0.5317
# epoch 406/6000; train loss: 0.2627, val_loss: 0.3941 0.5467
# epoch 407/6000; train loss: 0.2626, val_loss: 0.4002 0.2675
# epoch 408/6000; train loss: 0.2625, val_loss: 0.4149 0.4471
# epoch 409/6000; train loss: 0.2623, val_loss: 0.4278 0.4615
# epoch 410/6000; train loss: 0.2621, val_loss: 0.4429 0.6275
# epoch 411/6000; train loss: 0.2619, val_loss: 0.4566 0.4979
# epoch 412/6000; train loss: 0.2618, val_loss: 0.4721 0.6770
# epoch 413/6000; train loss: 0.2618, val_loss: 0.4868 0.7025
# epoch 414/6000; train loss: 0.2617, val_loss: 0.4970 0.7204
# epoch 415/6000; train loss: 0.2617, val_loss: 0.5013 0.3009
# epoch 416/6000; train loss: 0.2617, val_loss: 0.4970 0.7226
# epoch 417/6000; train loss: 0.2617, val_loss: 0.4980 0.2987
# epoch 418/6000; train loss: 0.2617, val_loss: 0.4874 0.5014
# epoch 419/6000; train loss: 0.2617, val_loss: 0.4839 0.4987
# epoch 420/6000; train loss: 0.2617, val_loss: 0.4661 0.4846
# epoch 421/6000; train loss: 0.2617, val_loss: 0.4653 0.4842
# epoch 422/6000; train loss: 0.2617, val_loss: 0.4501 0.3625
# epoch 423/6000; train loss: 0.2616, val_loss: 0.4458 0.4692
# epoch 424/6000; train loss: 0.2616, val_loss: 0.4283 0.6061
# epoch 425/6000; train loss: 0.2616, val_loss: 0.4289 0.4557
# epoch 426/6000; train loss: 0.2616, val_loss: 0.4182 0.5875
# epoch 427/6000; train loss: 0.2616, val_loss: 0.4206 0.4575
# epoch 428/6000; train loss: 0.2616, val_loss: 0.4102 0.2653
# epoch 429/6000; train loss: 0.2616, val_loss: 0.4170 0.3317
# epoch 430/6000; train loss: 0.2616, val_loss: 0.4065 0.4400
# epoch 431/6000; train loss: 0.2616, val_loss: 0.4171 0.4481
# epoch 432/6000; train loss: 0.2617, val_loss: 0.4023 0.3211
# epoch 433/6000; train loss: 0.2618, val_loss: 0.4218 0.4604
# epoch 434/6000; train loss: 0.2619, val_loss: 0.4010 0.3201
# epoch 435/6000; train loss: 0.2622, val_loss: 0.4263 0.2659
# epoch 436/6000; train loss: 0.2627, val_loss: 0.3975 0.5504
# epoch 437/6000; train loss: 0.2633, val_loss: 0.4419 0.2701
# epoch 438/6000; train loss: 0.2644, val_loss: 0.4044 0.5656
# epoch 439/6000; train loss: 0.2655, val_loss: 0.4327 0.4684
# epoch 440/6000; train loss: 0.2670, val_loss: 0.3948 0.5488
# epoch 441/6000; train loss: 0.2679, val_loss: 0.4650 0.6869
# epoch 442/6000; train loss: 0.2684, val_loss: 0.4509 0.4911
# epoch 443/6000; train loss: 0.2672, val_loss: 0.4224 0.4567
# epoch 444/6000; train loss: 0.2650, val_loss: 0.3838 0.2635
# epoch 445/6000; train loss: 0.2629, val_loss: 0.3938 0.2627
# epoch 446/6000; train loss: 0.2616, val_loss: 0.4053 0.4387
# epoch 447/6000; train loss: 0.2615, val_loss: 0.4009 0.2628
# epoch 448/6000; train loss: 0.2621, val_loss: 0.3946 0.2653
# epoch 449/6000; train loss: 0.2631, val_loss: 0.3846 0.4053
# epoch 450/6000; train loss: 0.2638, val_loss: 0.3897 0.3197
# epoch 451/6000; train loss: 0.2639, val_loss: 0.3877 0.4116
# epoch 452/6000; train loss: 0.2633, val_loss: 0.3845 0.2624
# epoch 453/6000; train loss: 0.2624, val_loss: 0.3796 0.5179
# epoch 454/6000; train loss: 0.2616, val_loss: 0.3810 0.3173
# epoch 455/6000; train loss: 0.2613, val_loss: 0.3827 0.2625
# epoch 456/6000; train loss: 0.2614, val_loss: 0.3821 0.4031
# epoch 457/6000; train loss: 0.2619, val_loss: 0.3812 0.5213
# epoch 458/6000; train loss: 0.2623, val_loss: 0.3798 0.3188
# epoch 459/6000; train loss: 0.2624, val_loss: 0.3848 0.4076
# epoch 460/6000; train loss: 0.2624, val_loss: 0.3835 0.4049
# epoch 461/6000; train loss: 0.2620, val_loss: 0.3792 0.4024
# epoch 462/6000; train loss: 0.2616, val_loss: 0.3801 0.2641
# epoch 463/6000; train loss: 0.2613, val_loss: 0.3876 0.4124
# epoch 464/6000; train loss: 0.2612, val_loss: 0.3911 0.4189
# epoch 465/6000; train loss: 0.2613, val_loss: 0.3863 0.5285
# epoch 466/6000; train loss: 0.2614, val_loss: 0.3846 0.4080
# epoch 467/6000; train loss: 0.2616, val_loss: 0.3834 0.2642
# epoch 468/6000; train loss: 0.2617, val_loss: 0.3903 0.4193
# epoch 469/6000; train loss: 0.2617, val_loss: 0.3848 0.4073
# epoch 470/6000; train loss: 0.2616, val_loss: 0.3816 0.3129
# epoch 471/6000; train loss: 0.2615, val_loss: 0.3815 0.3151
# epoch 472/6000; train loss: 0.2614, val_loss: 0.3919 0.5428
# epoch 473/6000; train loss: 0.2612, val_loss: 0.3900 0.3169
# epoch 474/6000; train loss: 0.2612, val_loss: 0.3842 0.2623
# epoch 475/6000; train loss: 0.2611, val_loss: 0.3818 0.5215
# epoch 476/6000; train loss: 0.2611, val_loss: 0.3833 0.5248
# epoch 477/6000; train loss: 0.2612, val_loss: 0.3872 0.2613
# epoch 478/6000; train loss: 0.2612, val_loss: 0.3812 0.5212
# epoch 479/6000; train loss: 0.2613, val_loss: 0.3799 0.4045
# epoch 480/6000; train loss: 0.2613, val_loss: 0.3805 0.3139
# epoch 481/6000; train loss: 0.2613, val_loss: 0.3900 0.5395
# epoch 482/6000; train loss: 0.2613, val_loss: 0.3835 0.3141
# epoch 483/6000; train loss: 0.2613, val_loss: 0.3813 0.3130
# epoch 484/6000; train loss: 0.2613, val_loss: 0.3790 0.5158
# epoch 485/6000; train loss: 0.2613, val_loss: 0.3896 0.2616
# epoch 486/6000; train loss: 0.2613, val_loss: 0.3852 0.4095
# epoch 487/6000; train loss: 0.2613, val_loss: 0.3820 0.4078
# epoch 488/6000; train loss: 0.2612, val_loss: 0.3784 0.4010
# epoch 489/6000; train loss: 0.2613, val_loss: 0.3964 0.4281
# epoch 490/6000; train loss: 0.2613, val_loss: 0.3923 0.5438
# epoch 491/6000; train loss: 0.2613, val_loss: 0.3845 0.2623
# epoch 492/6000; train loss: 0.2613, val_loss: 0.3783 0.5136
# epoch 493/6000; train loss: 0.2614, val_loss: 0.4074 0.3269
# epoch 494/6000; train loss: 0.2615, val_loss: 0.4107 0.4334
# epoch 495/6000; train loss: 0.2617, val_loss: 0.4005 0.5631
# epoch 496/6000; train loss: 0.2618, val_loss: 0.3797 0.2632
# epoch 497/6000; train loss: 0.2620, val_loss: 0.3930 0.5466
# epoch 498/6000; train loss: 0.2623, val_loss: 0.3909 0.4194
# epoch 499/6000; train loss: 0.2627, val_loss: 0.4066 0.4372
# epoch 500/6000; train loss: 0.2632, val_loss: 0.3854 0.5292
# epoch 501/6000; train loss: 0.2636, val_loss: 0.3915 0.4156
# epoch 502/6000; train loss: 0.2641, val_loss: 0.3784 0.3973
# epoch 503/6000; train loss: 0.2643, val_loss: 0.4040 0.5732
# epoch 504/6000; train loss: 0.2646, val_loss: 0.3991 0.3240
# epoch 505/6000; train loss: 0.2644, val_loss: 0.3932 0.4185
# epoch 506/6000; train loss: 0.2638, val_loss: 0.3869 0.4025
# epoch 507/6000; train loss: 0.2630, val_loss: 0.3910 0.2649
# epoch 508/6000; train loss: 0.2623, val_loss: 0.3991 0.3237
# epoch 509/6000; train loss: 0.2617, val_loss: 0.3883 0.4062
# epoch 510/6000; train loss: 0.2612, val_loss: 0.3793 0.5160
# epoch 511/6000; train loss: 0.2610, val_loss: 0.3816 0.4051
# epoch 512/6000; train loss: 0.2610, val_loss: 0.3872 0.3157
# epoch 513/6000; train loss: 0.2611, val_loss: 0.3981 0.5584
# epoch 514/6000; train loss: 0.2615, val_loss: 0.3883 0.4074
# epoch 515/6000; train loss: 0.2617, val_loss: 0.3781 0.2647
# epoch 516/6000; train loss: 0.2619, val_loss: 0.3794 0.5171
# epoch 517/6000; train loss: 0.2621, val_loss: 0.3789 0.4011
# epoch 518/6000; train loss: 0.2620, val_loss: 0.3874 0.2621
# epoch 519/6000; train loss: 0.2619, val_loss: 0.3814 0.4021
# epoch 520/6000; train loss: 0.2616, val_loss: 0.3763 0.3983
# epoch 521/6000; train loss: 0.2613, val_loss: 0.3771 0.3985
# epoch 522/6000; train loss: 0.2611, val_loss: 0.3862 0.4095
# epoch 523/6000; train loss: 0.2609, val_loss: 0.3867 0.3140
# epoch 524/6000; train loss: 0.2609, val_loss: 0.3779 0.2614
# epoch 525/6000; train loss: 0.2608, val_loss: 0.3750 0.2619
# epoch 526/6000; train loss: 0.2608, val_loss: 0.3824 0.3131
# epoch 527/6000; train loss: 0.2608, val_loss: 0.3921 0.4227
# epoch 528/6000; train loss: 0.2609, val_loss: 0.3850 0.2620
# epoch 529/6000; train loss: 0.2609, val_loss: 0.3785 0.3117
# epoch 530/6000; train loss: 0.2610, val_loss: 0.3787 0.2625
# epoch 531/6000; train loss: 0.2610, val_loss: 0.3953 0.4178
# epoch 532/6000; train loss: 0.2610, val_loss: 0.3931 0.2622
# epoch 533/6000; train loss: 0.2611, val_loss: 0.3843 0.5274
# epoch 534/6000; train loss: 0.2611, val_loss: 0.3780 0.3994
# epoch 535/6000; train loss: 0.2612, val_loss: 0.4002 0.5617
# epoch 536/6000; train loss: 0.2613, val_loss: 0.4070 0.5735
# epoch 537/6000; train loss: 0.2614, val_loss: 0.3989 0.4318
# epoch 538/6000; train loss: 0.2615, val_loss: 0.3827 0.2642
# epoch 539/6000; train loss: 0.2617, val_loss: 0.3932 0.2626
# epoch 540/6000; train loss: 0.2620, val_loss: 0.3914 0.5420
# epoch 541/6000; train loss: 0.2623, val_loss: 0.4003 0.4183
# epoch 542/6000; train loss: 0.2626, val_loss: 0.3829 0.3148
# epoch 543/6000; train loss: 0.2628, val_loss: 0.3915 0.5446
# epoch 544/6000; train loss: 0.2631, val_loss: 0.3810 0.4032
# epoch 545/6000; train loss: 0.2633, val_loss: 0.4077 0.4225
# epoch 546/6000; train loss: 0.2635, val_loss: 0.3958 0.2643
# epoch 547/6000; train loss: 0.2634, val_loss: 0.3913 0.2656
# epoch 548/6000; train loss: 0.2631, val_loss: 0.3797 0.3999
# epoch 549/6000; train loss: 0.2626, val_loss: 0.4122 0.4271
# epoch 550/6000; train loss: 0.2622, val_loss: 0.4328 0.3501
# epoch 551/6000; train loss: 0.2618, val_loss: 0.4092 0.4255
# epoch 552/6000; train loss: 0.2613, val_loss: 0.3897 0.5356
# epoch 553/6000; train loss: 0.2610, val_loss: 0.3842 0.3173
# epoch 554/6000; train loss: 0.2608, val_loss: 0.3895 0.2613
# epoch 555/6000; train loss: 0.2607, val_loss: 0.3964 0.5541
# epoch 556/6000; train loss: 0.2608, val_loss: 0.3850 0.4073
# epoch 557/6000; train loss: 0.2609, val_loss: 0.3820 0.4026
# epoch 558/6000; train loss: 0.2611, val_loss: 0.3837 0.4054
# epoch 559/6000; train loss: 0.2614, val_loss: 0.3848 0.4107
# epoch 560/6000; train loss: 0.2616, val_loss: 0.3838 0.4055
# epoch 561/6000; train loss: 0.2619, val_loss: 0.3772 0.5086
# epoch 562/6000; train loss: 0.2621, val_loss: 0.3982 0.3228
# epoch 563/6000; train loss: 0.2624, val_loss: 0.3964 0.5484
# epoch 564/6000; train loss: 0.2625, val_loss: 0.3897 0.4114
# epoch 565/6000; train loss: 0.2623, val_loss: 0.3813 0.4041
# epoch 566/6000; train loss: 0.2622, val_loss: 0.4083 0.5786
# epoch 567/6000; train loss: 0.2620, val_loss: 0.4200 0.4413
# epoch 568/6000; train loss: 0.2618, val_loss: 0.4140 0.2629
# epoch 569/6000; train loss: 0.2614, val_loss: 0.3978 0.3253
# epoch 570/6000; train loss: 0.2611, val_loss: 0.3872 0.5299
# epoch 571/6000; train loss: 0.2609, val_loss: 0.3816 0.4084
# epoch 572/6000; train loss: 0.2607, val_loss: 0.3827 0.5252
# epoch 573/6000; train loss: 0.2606, val_loss: 0.3824 0.2616
# epoch 574/6000; train loss: 0.2606, val_loss: 0.3779 0.5102
# epoch 575/6000; train loss: 0.2607, val_loss: 0.3727 0.3957
# epoch 576/6000; train loss: 0.2608, val_loss: 0.3741 0.3953
# epoch 577/6000; train loss: 0.2610, val_loss: 0.3835 0.4117
# epoch 578/6000; train loss: 0.2612, val_loss: 0.3767 0.3115
# epoch 579/6000; train loss: 0.2613, val_loss: 0.3749 0.3116
# epoch 580/6000; train loss: 0.2615, val_loss: 0.3791 0.4014
# epoch 581/6000; train loss: 0.2616, val_loss: 0.4111 0.5829
# epoch 582/6000; train loss: 0.2619, val_loss: 0.4223 0.6013
# epoch 583/6000; train loss: 0.2621, val_loss: 0.4102 0.2647
# epoch 584/6000; train loss: 0.2621, val_loss: 0.3912 0.5357
# epoch 585/6000; train loss: 0.2620, val_loss: 0.3973 0.3237
# epoch 586/6000; train loss: 0.2619, val_loss: 0.3968 0.2629
# epoch 587/6000; train loss: 0.2618, val_loss: 0.4014 0.4340
# epoch 588/6000; train loss: 0.2615, val_loss: 0.3899 0.3197
# epoch 589/6000; train loss: 0.2613, val_loss: 0.3798 0.4007
# epoch 590/6000; train loss: 0.2610, val_loss: 0.3733 0.5004
# epoch 591/6000; train loss: 0.2608, val_loss: 0.3826 0.5255
# epoch 592/6000; train loss: 0.2607, val_loss: 0.3862 0.3152
# epoch 593/6000; train loss: 0.2607, val_loss: 0.3791 0.4053
# epoch 594/6000; train loss: 0.2606, val_loss: 0.3838 0.4087
# epoch 595/6000; train loss: 0.2606, val_loss: 0.3880 0.4115
# epoch 596/6000; train loss: 0.2605, val_loss: 0.3991 0.4231
# epoch 597/6000; train loss: 0.2606, val_loss: 0.3902 0.4121
# epoch 598/6000; train loss: 0.2605, val_loss: 0.3821 0.4088
# epoch 599/6000; train loss: 0.2605, val_loss: 0.3888 0.4131
# epoch 600/6000; train loss: 0.2605, val_loss: 0.3966 0.3206
# epoch 601/6000; train loss: 0.2605, val_loss: 0.4046 0.4252
# epoch 602/6000; train loss: 0.2605, val_loss: 0.3921 0.3167
# epoch 603/6000; train loss: 0.2605, val_loss: 0.3832 0.5236
# epoch 604/6000; train loss: 0.2605, val_loss: 0.3790 0.4054
# epoch 605/6000; train loss: 0.2605, val_loss: 0.3920 0.4229
# epoch 606/6000; train loss: 0.2605, val_loss: 0.3916 0.5419
# epoch 607/6000; train loss: 0.2606, val_loss: 0.3830 0.2612
# epoch 608/6000; train loss: 0.2606, val_loss: 0.3769 0.4000
# epoch 609/6000; train loss: 0.2608, val_loss: 0.3971 0.4293
# epoch 610/6000; train loss: 0.2611, val_loss: 0.3962 0.5497
# epoch 611/6000; train loss: 0.2615, val_loss: 0.3949 0.2642
# epoch 612/6000; train loss: 0.2621, val_loss: 0.3795 0.4010
# epoch 613/6000; train loss: 0.2630, val_loss: 0.4277 0.6180
# epoch 614/6000; train loss: 0.2645, val_loss: 0.4365 0.4748
# epoch 615/6000; train loss: 0.2663, val_loss: 0.4369 0.4695
# epoch 616/6000; train loss: 0.2678, val_loss: 0.4168 0.3467
# epoch 617/6000; train loss: 0.2684, val_loss: 0.4319 0.4618
# epoch 618/6000; train loss: 0.2671, val_loss: 0.4448 0.2790
# epoch 619/6000; train loss: 0.2657, val_loss: 0.4317 0.6044
# epoch 620/6000; train loss: 0.2636, val_loss: 0.4296 0.2744
# epoch 621/6000; train loss: 0.2613, val_loss: 0.4885 0.5428
# epoch 622/6000; train loss: 0.2613, val_loss: 0.3880 0.4160
# epoch 623/6000; train loss: 0.2628, val_loss: 0.5159 0.4483
# epoch 624/6000; train loss: 0.2762, val_loss: 0.6549 0.6009
# epoch 625/6000; train loss: 0.3206, val_loss: 0.6376 0.5694
# epoch 626/6000; train loss: 0.3095, val_loss: 0.4782 0.4863
# epoch 627/6000; train loss: 0.2818, val_loss: 0.5764 0.4334
# epoch 628/6000; train loss: 0.2855, val_loss: 0.7408 0.6659
# epoch 629/6000; train loss: 0.2732, val_loss: 0.8882 0.8072
# epoch 630/6000; train loss: 0.2791, val_loss: 0.9873 0.9621
# epoch 631/6000; train loss: 0.2818, val_loss: 1.3129 0.9659
# epoch 632/6000; train loss: 0.2724, val_loss: 1.2345 1.3021
# epoch 633/6000; train loss: 0.2772, val_loss: 1.2277 1.1576
# epoch 634/6000; train loss: 0.2778, val_loss: 1.4650 1.8159
# epoch 635/6000; train loss: 0.2728, val_loss: 1.3228 1.3710
# epoch 636/6000; train loss: 0.2764, val_loss: 1.0637 0.9188
# epoch 637/6000; train loss: 0.2727, val_loss: 0.9821 0.8260
# epoch 638/6000; train loss: 0.2691, val_loss: 0.7554 0.8534
# epoch 639/6000; train loss: 0.2756, val_loss: 0.5227 0.6532
# epoch 640/6000; train loss: 0.2713, val_loss: 0.4322 0.4000
# epoch 641/6000; train loss: 0.2640, val_loss: 0.3950 0.3234
# epoch 642/6000; train loss: 0.2713, val_loss: 0.4097 0.3308
# epoch 643/6000; train loss: 0.2692, val_loss: 0.4220 0.5419
# epoch 644/6000; train loss: 0.2648, val_loss: 0.4242 0.4236
# epoch 645/6000; train loss: 0.2677, val_loss: 0.4461 0.5871
# epoch 646/6000; train loss: 0.2670, val_loss: 0.4507 0.3378
# epoch 647/6000; train loss: 0.2654, val_loss: 0.4415 0.3438
# epoch 648/6000; train loss: 0.2662, val_loss: 0.4236 0.4464
# epoch 649/6000; train loss: 0.2653, val_loss: 0.4323 0.5549
# epoch 650/6000; train loss: 0.2639, val_loss: 0.4407 0.3734
# epoch 651/6000; train loss: 0.2661, val_loss: 0.4231 0.3063
# epoch 652/6000; train loss: 0.2648, val_loss: 0.4336 0.4771
# epoch 653/6000; train loss: 0.2625, val_loss: 0.4524 0.4942
# epoch 654/6000; train loss: 0.2647, val_loss: 0.4411 0.3669
# epoch 655/6000; train loss: 0.2640, val_loss: 0.4404 0.3187
# epoch 656/6000; train loss: 0.2626, val_loss: 0.4461 0.3171
# epoch 657/6000; train loss: 0.2634, val_loss: 0.4342 0.3634
# epoch 658/6000; train loss: 0.2629, val_loss: 0.4149 0.4435
# epoch 659/6000; train loss: 0.2627, val_loss: 0.4049 0.2866
# epoch 660/6000; train loss: 0.2628, val_loss: 0.4033 0.4121
# epoch 661/6000; train loss: 0.2625, val_loss: 0.3895 0.5237
# epoch 662/6000; train loss: 0.2621, val_loss: 0.3853 0.2742
# epoch 663/6000; train loss: 0.2628, val_loss: 0.3906 0.3335
# epoch 664/6000; train loss: 0.2624, val_loss: 0.3847 0.4147
# epoch 665/6000; train loss: 0.2618, val_loss: 0.3848 0.5132
# epoch 666/6000; train loss: 0.2623, val_loss: 0.3904 0.4151
# epoch 667/6000; train loss: 0.2621, val_loss: 0.3892 0.3293
# epoch 668/6000; train loss: 0.2618, val_loss: 0.3907 0.2818
# epoch 669/6000; train loss: 0.2620, val_loss: 0.3899 0.5240
# epoch 670/6000; train loss: 0.2618, val_loss: 0.3896 0.4032
# epoch 671/6000; train loss: 0.2618, val_loss: 0.3905 0.3338
# epoch 672/6000; train loss: 0.2619, val_loss: 0.3838 0.2750
# epoch 673/6000; train loss: 0.2617, val_loss: 0.3848 0.5156
# epoch 674/6000; train loss: 0.2615, val_loss: 0.3862 0.4107
# epoch 675/6000; train loss: 0.2617, val_loss: 0.3812 0.4100
# epoch 676/6000; train loss: 0.2617, val_loss: 0.3832 0.4109
# epoch 677/6000; train loss: 0.2615, val_loss: 0.3848 0.2715
# epoch 678/6000; train loss: 0.2616, val_loss: 0.3827 0.3199
# epoch 679/6000; train loss: 0.2615, val_loss: 0.3841 0.2684
# epoch 680/6000; train loss: 0.2615, val_loss: 0.3872 0.2682
# epoch 681/6000; train loss: 0.2615, val_loss: 0.3860 0.5159
# epoch 682/6000; train loss: 0.2614, val_loss: 0.3863 0.3210
# epoch 683/6000; train loss: 0.2614, val_loss: 0.3898 0.4122
# epoch 684/6000; train loss: 0.2615, val_loss: 0.3893 0.2669
# epoch 685/6000; train loss: 0.2614, val_loss: 0.3904 0.3248
# epoch 686/6000; train loss: 0.2614, val_loss: 0.3920 0.4132
# epoch 687/6000; train loss: 0.2614, val_loss: 0.3929 0.3256
# epoch 688/6000; train loss: 0.2614, val_loss: 0.3945 0.4275
# epoch 689/6000; train loss: 0.2613, val_loss: 0.3936 0.4271
# epoch 690/6000; train loss: 0.2614, val_loss: 0.3956 0.4237
# epoch 691/6000; train loss: 0.2613, val_loss: 0.3969 0.3270
# epoch 692/6000; train loss: 0.2613, val_loss: 0.3954 0.5302
# epoch 693/6000; train loss: 0.2613, val_loss: 0.3969 0.4314
# epoch 694/6000; train loss: 0.2613, val_loss: 0.3969 0.5316
# epoch 695/6000; train loss: 0.2613, val_loss: 0.3963 0.4260
# epoch 696/6000; train loss: 0.2613, val_loss: 0.3962 0.4308
# epoch 697/6000; train loss: 0.2613, val_loss: 0.3959 0.5307
# epoch 698/6000; train loss: 0.2613, val_loss: 0.3963 0.4309
# epoch 699/6000; train loss: 0.2612, val_loss: 0.3955 0.2668
# epoch 700/6000; train loss: 0.2612, val_loss: 0.3955 0.5307
# epoch 701/6000; train loss: 0.2612, val_loss: 0.3961 0.4312
# epoch 702/6000; train loss: 0.2612, val_loss: 0.3952 0.5301
# epoch 703/6000; train loss: 0.2612, val_loss: 0.3957 0.2665
# epoch 704/6000; train loss: 0.2612, val_loss: 0.3955 0.4251
# epoch 705/6000; train loss: 0.2612, val_loss: 0.3949 0.5297
# epoch 706/6000; train loss: 0.2612, val_loss: 0.3949 0.2659
# epoch 707/6000; train loss: 0.2612, val_loss: 0.3945 0.3237
# epoch 708/6000; train loss: 0.2612, val_loss: 0.3943 0.2654
# epoch 709/6000; train loss: 0.2612, val_loss: 0.3937 0.4218
# epoch 710/6000; train loss: 0.2612, val_loss: 0.3936 0.5281
# epoch 711/6000; train loss: 0.2612, val_loss: 0.3938 0.2651
# epoch 712/6000; train loss: 0.2612, val_loss: 0.3930 0.4209
# epoch 713/6000; train loss: 0.2612, val_loss: 0.3935 0.4296
# epoch 714/6000; train loss: 0.2611, val_loss: 0.3936 0.2646
# epoch 715/6000; train loss: 0.2611, val_loss: 0.3933 0.5276
# epoch 716/6000; train loss: 0.2611, val_loss: 0.3937 0.3228
# epoch 717/6000; train loss: 0.2611, val_loss: 0.3936 0.4236
# epoch 718/6000; train loss: 0.2611, val_loss: 0.3936 0.2642
# epoch 719/6000; train loss: 0.2611, val_loss: 0.3934 0.5276
# epoch 720/6000; train loss: 0.2611, val_loss: 0.3934 0.4231
# epoch 721/6000; train loss: 0.2611, val_loss: 0.3935 0.5278
# epoch 722/6000; train loss: 0.2611, val_loss: 0.3929 0.2640
# epoch 723/6000; train loss: 0.2611, val_loss: 0.3931 0.2642
# epoch 724/6000; train loss: 0.2611, val_loss: 0.3930 0.2641
# epoch 725/6000; train loss: 0.2611, val_loss: 0.3928 0.3223
# epoch 726/6000; train loss: 0.2611, val_loss: 0.3928 0.4209
# epoch 727/6000; train loss: 0.2611, val_loss: 0.3927 0.3221
# epoch 728/6000; train loss: 0.2611, val_loss: 0.3927 0.4294
# epoch 729/6000; train loss: 0.2611, val_loss: 0.3925 0.4209
# epoch 730/6000; train loss: 0.2611, val_loss: 0.3925 0.3218
# epoch 731/6000; train loss: 0.2611, val_loss: 0.3925 0.4294
# epoch 732/6000; train loss: 0.2611, val_loss: 0.3922 0.2635
# epoch 733/6000; train loss: 0.2610, val_loss: 0.3923 0.2635
# epoch 734/6000; train loss: 0.2610, val_loss: 0.3921 0.2634
# epoch 735/6000; train loss: 0.2610, val_loss: 0.3920 0.3212
# epoch 736/6000; train loss: 0.2610, val_loss: 0.3920 0.4290
# epoch 737/6000; train loss: 0.2610, val_loss: 0.3919 0.4290
# epoch 738/6000; train loss: 0.2610, val_loss: 0.3918 0.4206
# epoch 739/6000; train loss: 0.2610, val_loss: 0.3917 0.4289
# epoch 740/6000; train loss: 0.2610, val_loss: 0.3918 0.4208
# epoch 741/6000; train loss: 0.2610, val_loss: 0.3917 0.4289
# epoch 742/6000; train loss: 0.2610, val_loss: 0.3916 0.4205
# epoch 743/6000; train loss: 0.2610, val_loss: 0.3916 0.4289
# epoch 744/6000; train loss: 0.2610, val_loss: 0.3915 0.4205
# epoch 745/6000; train loss: 0.2610, val_loss: 0.3914 0.4202
# epoch 746/6000; train loss: 0.2610, val_loss: 0.3913 0.2629
# epoch 747/6000; train loss: 0.2610, val_loss: 0.3912 0.5245
# epoch 748/6000; train loss: 0.2610, val_loss: 0.3911 0.3203
# epoch 749/6000; train loss: 0.2610, val_loss: 0.3909 0.2628
# epoch 750/6000; train loss: 0.2610, val_loss: 0.3909 0.5240
# epoch 751/6000; train loss: 0.2610, val_loss: 0.3908 0.5239
# epoch 752/6000; train loss: 0.2610, val_loss: 0.3906 0.4278
# epoch 753/6000; train loss: 0.2610, val_loss: 0.3906 0.3199
# epoch 754/6000; train loss: 0.2610, val_loss: 0.3905 0.4189
# epoch 755/6000; train loss: 0.2610, val_loss: 0.3904 0.2626
# epoch 756/6000; train loss: 0.2609, val_loss: 0.3904 0.4276
# epoch 757/6000; train loss: 0.2609, val_loss: 0.3903 0.4275
# epoch 758/6000; train loss: 0.2609, val_loss: 0.3902 0.2625
# epoch 759/6000; train loss: 0.2609, val_loss: 0.3901 0.4182
# epoch 760/6000; train loss: 0.2609, val_loss: 0.3901 0.5229
# epoch 761/6000; train loss: 0.2609, val_loss: 0.3900 0.4180
# epoch 762/6000; train loss: 0.2609, val_loss: 0.3900 0.5229
# epoch 763/6000; train loss: 0.2609, val_loss: 0.3899 0.3194
# epoch 764/6000; train loss: 0.2609, val_loss: 0.3899 0.4271
# epoch 765/6000; train loss: 0.2609, val_loss: 0.3899 0.4271
# epoch 766/6000; train loss: 0.2609, val_loss: 0.3898 0.5226
# epoch 767/6000; train loss: 0.2609, val_loss: 0.3898 0.4175
# epoch 768/6000; train loss: 0.2609, val_loss: 0.3897 0.2624
# epoch 769/6000; train loss: 0.2609, val_loss: 0.3898 0.5225
# epoch 770/6000; train loss: 0.2609, val_loss: 0.3897 0.4172
# epoch 771/6000; train loss: 0.2609, val_loss: 0.3896 0.3193
# epoch 772/6000; train loss: 0.2609, val_loss: 0.3896 0.5223
# epoch 773/6000; train loss: 0.2609, val_loss: 0.3895 0.2625
# epoch 774/6000; train loss: 0.2609, val_loss: 0.3895 0.5222
# epoch 775/6000; train loss: 0.2609, val_loss: 0.3894 0.5221
# epoch 776/6000; train loss: 0.2609, val_loss: 0.3894 0.3192
# epoch 777/6000; train loss: 0.2609, val_loss: 0.3894 0.4166
# epoch 778/6000; train loss: 0.2609, val_loss: 0.3893 0.4165
# epoch 779/6000; train loss: 0.2609, val_loss: 0.3893 0.2625
# epoch 780/6000; train loss: 0.2608, val_loss: 0.3892 0.4163
# epoch 781/6000; train loss: 0.2608, val_loss: 0.3891 0.5217
# epoch 782/6000; train loss: 0.2608, val_loss: 0.3891 0.2624
# epoch 783/6000; train loss: 0.2608, val_loss: 0.3890 0.4158
# epoch 784/6000; train loss: 0.2608, val_loss: 0.3890 0.4262
# epoch 785/6000; train loss: 0.2608, val_loss: 0.3889 0.2625
# epoch 786/6000; train loss: 0.2608, val_loss: 0.3889 0.5214
# epoch 787/6000; train loss: 0.2608, val_loss: 0.3888 0.2624
# epoch 788/6000; train loss: 0.2608, val_loss: 0.3888 0.5213
# epoch 789/6000; train loss: 0.2608, val_loss: 0.3887 0.4152
# epoch 790/6000; train loss: 0.2608, val_loss: 0.3886 0.4259
# epoch 791/6000; train loss: 0.2608, val_loss: 0.3886 0.4258
# epoch 792/6000; train loss: 0.2608, val_loss: 0.3885 0.4257
# epoch 793/6000; train loss: 0.2608, val_loss: 0.3884 0.5208
# epoch 794/6000; train loss: 0.2608, val_loss: 0.3884 0.4145
# epoch 795/6000; train loss: 0.2608, val_loss: 0.3883 0.3186
# epoch 796/6000; train loss: 0.2608, val_loss: 0.3883 0.5206
# epoch 797/6000; train loss: 0.2608, val_loss: 0.3882 0.3185
# epoch 798/6000; train loss: 0.2608, val_loss: 0.3881 0.2624
# epoch 799/6000; train loss: 0.2608, val_loss: 0.3880 0.4252
# epoch 800/6000; train loss: 0.2608, val_loss: 0.3879 0.4136
# epoch 801/6000; train loss: 0.2608, val_loss: 0.3879 0.3183
# epoch 802/6000; train loss: 0.2608, val_loss: 0.3878 0.5199
# epoch 803/6000; train loss: 0.2608, val_loss: 0.3877 0.5198
# epoch 804/6000; train loss: 0.2607, val_loss: 0.3876 0.4131
# epoch 805/6000; train loss: 0.2607, val_loss: 0.3876 0.4246
# epoch 806/6000; train loss: 0.2607, val_loss: 0.3874 0.4126
# epoch 807/6000; train loss: 0.2607, val_loss: 0.3873 0.4125
# epoch 808/6000; train loss: 0.2607, val_loss: 0.3872 0.2624
# epoch 809/6000; train loss: 0.2607, val_loss: 0.3871 0.4241
# epoch 810/6000; train loss: 0.2607, val_loss: 0.3870 0.3179
# epoch 811/6000; train loss: 0.2607, val_loss: 0.3870 0.2624
# epoch 812/6000; train loss: 0.2607, val_loss: 0.3869 0.3178
# epoch 813/6000; train loss: 0.2607, val_loss: 0.3868 0.3178
# epoch 814/6000; train loss: 0.2607, val_loss: 0.3867 0.4235
# epoch 815/6000; train loss: 0.2607, val_loss: 0.3866 0.3177
# epoch 816/6000; train loss: 0.2607, val_loss: 0.3864 0.4232
# epoch 817/6000; train loss: 0.2607, val_loss: 0.3863 0.2624
# epoch 818/6000; train loss: 0.2607, val_loss: 0.3862 0.4105
# epoch 819/6000; train loss: 0.2607, val_loss: 0.3861 0.4103
# epoch 820/6000; train loss: 0.2607, val_loss: 0.3860 0.4101
# epoch 821/6000; train loss: 0.2607, val_loss: 0.3858 0.4098
# epoch 822/6000; train loss: 0.2607, val_loss: 0.3857 0.4097
# epoch 823/6000; train loss: 0.2607, val_loss: 0.3857 0.2624
# epoch 824/6000; train loss: 0.2607, val_loss: 0.3855 0.4220
# epoch 825/6000; train loss: 0.2607, val_loss: 0.3854 0.4090
# epoch 826/6000; train loss: 0.2607, val_loss: 0.3853 0.4217
# epoch 827/6000; train loss: 0.2607, val_loss: 0.3851 0.5161
# epoch 828/6000; train loss: 0.2607, val_loss: 0.3850 0.5160
# epoch 829/6000; train loss: 0.2607, val_loss: 0.3848 0.5157
# epoch 830/6000; train loss: 0.2606, val_loss: 0.3847 0.2623
# epoch 831/6000; train loss: 0.2606, val_loss: 0.3846 0.2623
# epoch 832/6000; train loss: 0.2606, val_loss: 0.3844 0.3166
# epoch 833/6000; train loss: 0.2606, val_loss: 0.3843 0.3165
# epoch 834/6000; train loss: 0.2606, val_loss: 0.3842 0.3165
# epoch 835/6000; train loss: 0.2606, val_loss: 0.3840 0.3164
# epoch 836/6000; train loss: 0.2606, val_loss: 0.3839 0.3163
# epoch 837/6000; train loss: 0.2606, val_loss: 0.3837 0.3163
# epoch 838/6000; train loss: 0.2606, val_loss: 0.3836 0.5140
# epoch 839/6000; train loss: 0.2606, val_loss: 0.3834 0.5136
# epoch 840/6000; train loss: 0.2606, val_loss: 0.3833 0.2623
# epoch 841/6000; train loss: 0.2606, val_loss: 0.3831 0.4190
# epoch 842/6000; train loss: 0.2606, val_loss: 0.3830 0.4189
# epoch 843/6000; train loss: 0.2606, val_loss: 0.3827 0.3157
# epoch 844/6000; train loss: 0.2606, val_loss: 0.3827 0.4185
# epoch 845/6000; train loss: 0.2606, val_loss: 0.3825 0.4183
# epoch 846/6000; train loss: 0.2606, val_loss: 0.3824 0.5122
# epoch 847/6000; train loss: 0.2606, val_loss: 0.3820 0.3154
# epoch 848/6000; train loss: 0.2606, val_loss: 0.3820 0.3154
# epoch 849/6000; train loss: 0.2606, val_loss: 0.3817 0.5111
# epoch 850/6000; train loss: 0.2606, val_loss: 0.3818 0.3153
# epoch 851/6000; train loss: 0.2606, val_loss: 0.3813 0.4022
# epoch 852/6000; train loss: 0.2606, val_loss: 0.3815 0.2622
# epoch 853/6000; train loss: 0.2606, val_loss: 0.3809 0.4165
# epoch 854/6000; train loss: 0.2606, val_loss: 0.3813 0.3151
# epoch 855/6000; train loss: 0.2606, val_loss: 0.3805 0.4008
# epoch 856/6000; train loss: 0.2606, val_loss: 0.3812 0.4015
# epoch 857/6000; train loss: 0.2606, val_loss: 0.3800 0.5085
# epoch 858/6000; train loss: 0.2606, val_loss: 0.3813 0.5108
# epoch 859/6000; train loss: 0.2606, val_loss: 0.3793 0.5076
# epoch 860/6000; train loss: 0.2607, val_loss: 0.3816 0.2632
# epoch 861/6000; train loss: 0.2608, val_loss: 0.3786 0.5065
# epoch 862/6000; train loss: 0.2609, val_loss: 0.3826 0.3168
# epoch 863/6000; train loss: 0.2612, val_loss: 0.3779 0.2612
# epoch 864/6000; train loss: 0.2616, val_loss: 0.3851 0.2669
# epoch 865/6000; train loss: 0.2623, val_loss: 0.3776 0.4126
# epoch 866/6000; train loss: 0.2636, val_loss: 0.3901 0.3240
# epoch 867/6000; train loss: 0.2654, val_loss: 0.3788 0.2653
# epoch 868/6000; train loss: 0.2676, val_loss: 0.3953 0.4121
# epoch 869/6000; train loss: 0.2698, val_loss: 0.3786 0.3152
# epoch 870/6000; train loss: 0.2679, val_loss: 0.3890 0.2702
# epoch 871/6000; train loss: 0.2657, val_loss: 0.3759 0.3124
# epoch 872/6000; train loss: 0.2634, val_loss: 0.3783 0.4111
# epoch 873/6000; train loss: 0.2617, val_loss: 0.3755 0.3930
# epoch 874/6000; train loss: 0.2607, val_loss: 0.3747 0.3116
# epoch 875/6000; train loss: 0.2606, val_loss: 0.3763 0.4094
# epoch 876/6000; train loss: 0.2611, val_loss: 0.3745 0.2631
# epoch 877/6000; train loss: 0.2618, val_loss: 0.3797 0.3158
# epoch 878/6000; train loss: 0.2626, val_loss: 0.3749 0.5010
# epoch 879/6000; train loss: 0.2632, val_loss: 0.3817 0.4142
# epoch 880/6000; train loss: 0.2633, val_loss: 0.3754 0.5022
# epoch 881/6000; train loss: 0.2629, val_loss: 0.3790 0.4119
# epoch 882/6000; train loss: 0.2621, val_loss: 0.3749 0.3913
# epoch 883/6000; train loss: 0.2613, val_loss: 0.3775 0.2619
# epoch 884/6000; train loss: 0.2607, val_loss: 0.3747 0.4091
# epoch 885/6000; train loss: 0.2605, val_loss: 0.3750 0.4097
# epoch 886/6000; train loss: 0.2606, val_loss: 0.3775 0.4115
# epoch 887/6000; train loss: 0.2608, val_loss: 0.3734 0.2615
# epoch 888/6000; train loss: 0.2612, val_loss: 0.3787 0.5071
# epoch 889/6000; train loss: 0.2614, val_loss: 0.3737 0.4994
# epoch 890/6000; train loss: 0.2615, val_loss: 0.3778 0.3943
# epoch 891/6000; train loss: 0.2613, val_loss: 0.3738 0.4083
# epoch 892/6000; train loss: 0.2610, val_loss: 0.3769 0.3945
# epoch 893/6000; train loss: 0.2608, val_loss: 0.3741 0.3901
# epoch 894/6000; train loss: 0.2605, val_loss: 0.3749 0.5012
# epoch 895/6000; train loss: 0.2604, val_loss: 0.3752 0.2612
# epoch 896/6000; train loss: 0.2605, val_loss: 0.3735 0.3104
# epoch 897/6000; train loss: 0.2605, val_loss: 0.3757 0.2620
# epoch 898/6000; train loss: 0.2607, val_loss: 0.3732 0.2609
# epoch 899/6000; train loss: 0.2608, val_loss: 0.3756 0.2626
# epoch 900/6000; train loss: 0.2608, val_loss: 0.3727 0.3872
# epoch 901/6000; train loss: 0.2608, val_loss: 0.3755 0.4097
# epoch 902/6000; train loss: 0.2607, val_loss: 0.3725 0.2610
# epoch 903/6000; train loss: 0.2606, val_loss: 0.3745 0.4090
# epoch 904/6000; train loss: 0.2605, val_loss: 0.3733 0.2609
# epoch 905/6000; train loss: 0.2604, val_loss: 0.3735 0.2611
# epoch 906/6000; train loss: 0.2604, val_loss: 0.3736 0.2610
# epoch 907/6000; train loss: 0.2604, val_loss: 0.3731 0.4985
# epoch 908/6000; train loss: 0.2604, val_loss: 0.3737 0.3888
# epoch 909/6000; train loss: 0.2604, val_loss: 0.3725 0.4977
# epoch 910/6000; train loss: 0.2605, val_loss: 0.3739 0.4087
# epoch 911/6000; train loss: 0.2605, val_loss: 0.3721 0.3861
# epoch 912/6000; train loss: 0.2605, val_loss: 0.3736 0.2614
# epoch 913/6000; train loss: 0.2605, val_loss: 0.3722 0.3096
# epoch 914/6000; train loss: 0.2605, val_loss: 0.3733 0.3882
# epoch 915/6000; train loss: 0.2605, val_loss: 0.3721 0.4969
# epoch 916/6000; train loss: 0.2604, val_loss: 0.3733 0.3102
# epoch 917/6000; train loss: 0.2604, val_loss: 0.3722 0.3096
# epoch 918/6000; train loss: 0.2604, val_loss: 0.3730 0.4982
# epoch 919/6000; train loss: 0.2604, val_loss: 0.3726 0.3875
# epoch 920/6000; train loss: 0.2604, val_loss: 0.3728 0.3099
# epoch 921/6000; train loss: 0.2604, val_loss: 0.3729 0.4078
# epoch 922/6000... 1/5: train loss: 0.2603, val_loss: 0.3879
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13160\3115545668.py in <module>
#       8                        epochs=6000,
#       9                        dataloader=dl_lrdown2lr)
# ---> 10 history = trainer.train()
#
# ~\AppData\Local\Temp\ipykernel_13160\901660328.py in train(self)
#      45             item=1
#      46             with torch.no_grad():
# ---> 47                 for batch in self.dataloader['test']:
#      48                     data = batch[0].to(device)
#      49                     preds = self.model(data)
#
# C:\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# C:\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# C:\anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
# ---> 54         return self.collate_fn(data)
#
# C:\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py in default_collate(batch)
#     263             >>> default_collate(batch)  # Handle `CustomType` automatically
#     264     """
# --> 265     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# C:\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py in collate(batch, collate_fn_map)
#     140
#     141         if isinstance(elem, tuple):
# --> 142             return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     143         else:
#     144             try:
#
# C:\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py in <listcomp>(.0)
#     140
#     141         if isinstance(elem, tuple):
# --> 142             return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     143         else:
#     144             try:
#
# C:\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py in collate(batch, collate_fn_map)
#     117     if collate_fn_map is not None:
#     118         if elem_type in collate_fn_map:
# --> 119             return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     120
#     121         for collate_type in collate_fn_map:
#
# C:\anaconda3\lib\site-packages\torch\utils\data\_utils\collate.py in collate_tensor_fn(batch, collate_fn_map)
#     160         storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     161         out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 162     return torch.stack(batch, 0, out=out)
#     163
#     164
#
# KeyboardInterrupt:

# %%
plot_history(history)

# %%
def plot_history(history):
    plt.plot(history.loss, label='train loss')
    plt.plot(history.val_loss, label='val loss')
    plt.legend()
    plt.show()

# %%
del images_lr_downscales

# %%
#model = model.to('cpu')
#test = images_lr_downscales[0]
test = images_lr[5].to(device)
test = test[None, :]
model.eval()
with torch.no_grad():
    preds = model(test)
img = preds[0].permute(1,2,0).to('cpu')
torchvision.utils.save_image(preds[0], 'out_from_downscaled_div2k.png')
plt.imshow(img)

ref = images_hr[5].to(device)
ref = ref[None, :]
ssim_after = ssim(preds, ref, data_range=1)
print(ssim_after)
# Out:
# tensor(0.9677, device='cuda:0')

# %%
ref = images_hr[5].to(device)
ref = ref[None, :]
ssim_after = ssim(preds, ref, data_range=1)
print(ssim_after)
# Out:
# tensor(0.9677, device='cuda:0')

# %%
preds[0]
# Out:
# tensor([[[0.3988, 0.4764, 0.4871,  ..., 0.2906, 0.2826, 0.2443],
#          [0.4762, 0.5701, 0.6083,  ..., 0.3974, 0.3654, 0.3017],
#          [0.5138, 0.5977, 0.6525,  ..., 0.4454, 0.4080, 0.3076],
#          ...,
#          [0.3915, 0.4510, 0.4814,  ..., 0.5718, 0.5544, 0.4468],
#          [0.3794, 0.4250, 0.4504,  ..., 0.5538, 0.5116, 0.3806],
#          [0.3281, 0.3726, 0.3903,  ..., 0.4510, 0.3786, 0.3043]],
#
#         [[0.3825, 0.4075, 0.4439,  ..., 0.2700, 0.2564, 0.3025],
#          [0.4281, 0.4572, 0.4878,  ..., 0.3000, 0.2896, 0.2574],
#          [0.4457, 0.4815, 0.5159,  ..., 0.3231, 0.3182, 0.2875],
#          ...,
#          [0.3442, 0.3874, 0.4122,  ..., 0.5190, 0.5033, 0.4227],
#          [0.3376, 0.3965, 0.4040,  ..., 0.5052, 0.4792, 0.3780],
#          [0.2725, 0.3815, 0.3893,  ..., 0.4535, 0.4007, 0.3075]],
#
#         [[0.3418, 0.3633, 0.4022,  ..., 0.1909, 0.2118, 0.2030],
#          [0.3665, 0.3584, 0.4041,  ..., 0.1411, 0.1710, 0.1944],
#          [0.3835, 0.3613, 0.4096,  ..., 0.1221, 0.1497, 0.1786],
#          ...,
#          [0.2752, 0.2431, 0.2643,  ..., 0.3455, 0.3699, 0.3320],
#          [0.2768, 0.2604, 0.2652,  ..., 0.3502, 0.3465, 0.2797],
#          [0.2368, 0.2734, 0.2958,  ..., 0.3551, 0.3252, 0.2529]]],
#        grad_fn=<SelectBackward0>)

# %%
torch.cuda.empty_cache()

# %%
test.device
# Out:
# device(type='cpu')

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
torchvision.utils.save_image(images_lr_downscales[0]/255., 'test2.png')

# %% [markdown]
# # deblur

# %%
class nn_deblur(nn.Module):
    def __init__(self, n_channels):
        super(nn_deblur, self).__init__()
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=n_channels, kernel_size=(3,3), stride=1, padding='same'),
            nn.Conv2d(in_channels=n_channels, out_channels=n_channels, kernel_size=(5,5), stride=1, padding='same'),
            #nn.Conv2d(in_channels=n_channels, out_channels=3, kernel_size=(7,7), stride=1, padding='same'),
            #nn.Conv2d(in_channels=n_channels, out_channels=3, kernel_size=(11,11), stride=1, padding='same')
        )
        self.conv_resc1 = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=(1,1), padding='same')
        
        #self.conv2 = nn.Sequential(
        #    nn.Conv2d(in_channels=3, out_channels=n_channels, kernel_size=(3,3), stride=1, padding='same'),
        #    nn.Conv2d(in_channels=n_channels, out_channels=n_channels, kernel_size=(5,5), stride=1, padding='same'),
        #    nn.Conv2d(in_channels=n_channels, out_channels=3, kernel_size=(7,7), stride=1, padding='same'),
            #nn.Conv2d(in_channels=n_channels, out_channels=3, kernel_size=(11,11), stride=1, padding='same')
        #)
        #self.conv_resc2 = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=(1,1), padding='same')
        
        self.act = nn.GELU()
        
    def forward(self, x):
        x = x.type(torch.cuda.FloatTensor)
        x = self.conv1(x) + self.conv_resc1(x)
        #x = self.conv2(x) + self.conv_resc2(x)
        x = self.act(x)
        x = torch.clamp(x, min=0, max=255)
        return x

# %%
ds_deblur_train = images_dataset(images_lr[:100], images_lr[:100])
ds_deblur_test = images_dataset(images_lr_test[:100], images_lr_test[:100])

BATCH_SIZE = 1

dl_deblur_train = DataLoader(ds_deblur_train,
                               batch_size=BATCH_SIZE,
                               shuffle=False)
dl_deblur_test = DataLoader(ds_deblur_test,
                               batch_size=BATCH_SIZE,
                               shuffle=False)

dl_deblur = {'train': dl_deblur_train, 'test': dl_deblur_test}

ds_deblur_withscale = images_dataset(images_lr_downscales[:10], images_lr[:10])
dl_deblur_withscale = DataLoader(ds_deblur_withscale,
                               batch_size=BATCH_SIZE,
                               shuffle=False)

dl_deblur_withscale = {'train': dl_deblur, 'test': dl_deblur_test}

# %%
model_deblur = nn_deblur(3).to(device)
print(model_deblur)

def loss_brisque(y_pred, y_true):
    loss = BRISQUELoss(data_range=255)(y_pred)
    loss = 100/loss + 0.01*nn.L1Loss()(y_pred, y_true)

    return loss

def loss_tv(y_pred, y_true):
    loss = TVLoss()(y_pred)
    loss = 10000/loss + 0.01*nn.L1Loss()(y_pred, y_true)
    return loss

def loss_agm(y_pred, y_true):
    y = y_pred[0]
    gy, gx, gc = torch.gradient(y)
    gnorm = torch.sqrt(gx**2 + gy**2)
    return torch.mean(gnorm) #+ nn.MSELoss()(y_pred, y_true)

def loss_fft(y_pred, y_true):
    return 1/(tensor2freq(y_pred)+1e-10) #+ 0.01*nn.L1Loss()(y_pred, y_true)

def loss_tv_psnr(y_pred, y_true):
    loss_tv = TVLoss()(y_pred)
    loss_tv = 10000/loss_tv
    loss_psnr = psnr(y_pred, y_true, data_range=255, convert_to_greyscale=True)
    loss_psnr = 100 - loss_psnr
    return loss_tv + 0.01*loss_psnr + 0.01*nn.L1Loss()(y_pred, y_true)

def loss_tv_ssim(y_pred, y_true):
    loss_tv = TVLoss()(y_pred)
    loss_tv = 10000/loss_tv
    loss_ssim = ssim(y_pred, y_true, data_range=255)
    loss_ssim = 1 - loss_psnr
    return loss_tv + 0.1*loss_ssim #+ 0.01*nn.L1Loss()(y_pred, y_true)

criterion_deblur = loss_tv
optimizer = torch.optim.AdamW(model_deblur.parameters(), lr=1e-3)
exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)
trainer = torch_trainer(model=model_deblur,
                       criterion=criterion_deblur,
                       optimizer=optimizer,
                       epochs=2000,
                       dataloader=dl_deblur)
history = trainer.train()
# Out:
# nn_deblur(
#   (conv1): Sequential(
#     (0): Conv2d(3, 3, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): Conv2d(3, 3, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   )
#   (conv_resc1): Conv2d(3, 3, kernel_size=(1, 1), stride=(1, 1), padding=same)
#   (act): GELU(approximate='none')
# )
# epoch 1/2000; train loss: 1.0029, val_loss: 0.8742s: 0.552100
# epoch 2/2000; train loss: 0.6986, val_loss: 0.7482s: 0.511142
# epoch 3/2000; train loss: 0.6267, val_loss: 0.7112s: 0.505082
# epoch 4/2000; train loss: 0.6000, val_loss: 0.6789s: 0.491712
# epoch 5/2000; train loss: 0.5799, val_loss: 0.6497s: 0.475389
# epoch 6/2000; train loss: 0.5614, val_loss: 0.6191s: 0.456797
# epoch 7/2000; train loss: 0.5440, val_loss: 0.5961s: 0.440991
# epoch 8/2000; train loss: 0.5262, val_loss: 0.5727s: 0.423961
# epoch 9/2000; train loss: 0.5087, val_loss: 0.5472s: 0.406827
# epoch 10/2000; train loss: 0.4955, val_loss: 0.5288s: 0.395472
# epoch 11/2000; train loss: 0.4835, val_loss: 0.5084s: 0.384788
# epoch 12/2000; train loss: 0.4743, val_loss: 0.4970s: 0.379084
# epoch 13/2000; train loss: 0.4672, val_loss: 0.4914s: 0.374770
# epoch 14/2000; train loss: 0.4629, val_loss: 0.4876s: 0.370714
# epoch 15/2000; train loss: 0.4580, val_loss: 0.4821s: 0.366076
# epoch 16/2000; train loss: 0.4529, val_loss: 0.4778s: 0.360121
# epoch 17/2000; train loss: 0.4480, val_loss: 0.4725s: 0.353678
# epoch 18/2000; train loss: 0.4424, val_loss: 0.4676s: 0.346925
# epoch 19/2000; train loss: 0.4378, val_loss: 0.4633s: 0.341576
# epoch 20/2000; train loss: 0.4336, val_loss: 0.4592s: 0.338333
# epoch 21/2000; train loss: 0.4301, val_loss: 0.4556s: 0.335592
# epoch 22/2000; train loss: 0.4258, val_loss: 0.4522s: 0.332156
# epoch 23/2000; train loss: 0.4229, val_loss: 0.4491s: 0.329022
# epoch 24/2000; train loss: 0.4191, val_loss: 0.4447s: 0.325091
# epoch 25/2000; train loss: 0.4153, val_loss: 0.4410s: 0.322347
# epoch 26/2000; train loss: 0.4119, val_loss: 0.4402s: 0.321510
# epoch 27/2000; train loss: 0.4120, val_loss: 0.4371s: 0.321102
# epoch 28/2000; train loss: 0.4106, val_loss: 0.4346s: 0.321271
# epoch 29/2000; train loss: 0.4075, val_loss: 0.4345s: 0.321846
# epoch 30/2000; train loss: 0.4080, val_loss: 0.4337s: 0.322245
# epoch 31/2000; train loss: 0.4070, val_loss: 0.4313s: 0.322137
# epoch 32/2000; train loss: 0.4052, val_loss: 0.4309s: 0.322613
# epoch 33/2000; train loss: 0.4052, val_loss: 0.4309s: 0.323509
# epoch 34/2000; train loss: 0.4055, val_loss: 0.4294s: 0.323209
# epoch 35/2000; train loss: 0.4047, val_loss: 0.4275s: 0.322994
# epoch 36/2000; train loss: 0.4033, val_loss: 0.4278s: 0.323075
# epoch 37/2000; train loss: 0.4024, val_loss: 0.4270s: 0.322478
# epoch 38/2000; train loss: 0.4020, val_loss: 0.4269s: 0.322670
# epoch 39/2000; train loss: 0.4014, val_loss: 0.4260s: 0.322469
# epoch 40/2000; train loss: 0.4015, val_loss: 0.4253s: 0.321960
# epoch 41/2000; train loss: 0.4005, val_loss: 0.4243s: 0.321053
# epoch 42/2000; train loss: 0.3990, val_loss: 0.4246s: 0.320743
# epoch 43/2000; train loss: 0.3991, val_loss: 0.4225s: 0.320446
# epoch 44/2000; train loss: 0.3989, val_loss: 0.4226s: 0.320225
# epoch 45/2000; train loss: 0.3983, val_loss: 0.4217s: 0.319826
# epoch 46/2000; train loss: 0.3974, val_loss: 0.4211s: 0.319617
# epoch 47/2000; train loss: 0.3962, val_loss: 0.4206s: 0.318511
# epoch 48/2000; train loss: 0.3955, val_loss: 0.4199s: 0.318006
# epoch 49/2000; train loss: 0.3967, val_loss: 0.4194s: 0.317599
# epoch 50/2000; train loss: 0.3943, val_loss: 0.4188s: 0.316894
# epoch 51/2000; train loss: 0.3938, val_loss: 0.4183s: 0.316288
# epoch 52/2000; train loss: 0.3947, val_loss: 0.4171s: 0.316083
# epoch 53/2000; train loss: 0.3925, val_loss: 0.4173s: 0.314971
# epoch 54/2000; train loss: 0.3937, val_loss: 0.4169s: 0.314573
# epoch 55/2000; train loss: 0.3936, val_loss: 0.4163s: 0.313769
# epoch 56/2000; train loss: 0.3921, val_loss: 0.4157s: 0.313063
# epoch 57/2000; train loss: 0.3920, val_loss: 0.4170s: 0.312857
# epoch 58/2000; train loss: 0.3905, val_loss: 0.4141s: 0.311070
# epoch 59/2000; train loss: 0.3891, val_loss: 0.4135s: 0.309941
# epoch 60/2000; train loss: 0.3890, val_loss: 0.4130s: 0.308835
# epoch 61/2000; train loss: 0.3879, val_loss: 0.4116s: 0.307630
# epoch 62/2000; train loss: 0.3883, val_loss: 0.4106s: 0.306216
# epoch 63/2000; train loss: 0.3869, val_loss: 0.4093s: 0.304606
# epoch 64/2000; train loss: 0.3848, val_loss: 0.4085s: 0.302993
# epoch 65/2000; train loss: 0.3839, val_loss: 0.4061s: 0.300485
# epoch 66/2000; train loss: 0.3809, val_loss: 0.4038s: 0.297661
# epoch 67/2000; train loss: 0.3799, val_loss: 0.4022s: 0.295338
# epoch 68/2000; train loss: 0.3785, val_loss: 0.4003s: 0.292922
# epoch 69/2000; train loss: 0.3758, val_loss: 0.3978s: 0.290503
# epoch 70/2000; train loss: 0.3741, val_loss: 0.3965s: 0.289278
# epoch 71/2000; train loss: 0.3722, val_loss: 0.3944s: 0.288165
# epoch 72/2000; train loss: 0.3699, val_loss: 0.3937s: 0.287944
# epoch 73/2000; train loss: 0.3710, val_loss: 0.3920s: 0.287937
# epoch 74/2000; train loss: 0.3680, val_loss: 0.3908s: 0.287720
# epoch 75/2000; train loss: 0.3685, val_loss: 0.3928s: 0.288808
# epoch 76/2000; train loss: 0.3677, val_loss: 0.3890s: 0.288128
# epoch 77/2000; train loss: 0.3658, val_loss: 0.3884s: 0.288290
# epoch 78/2000; train loss: 0.3659, val_loss: 0.3877s: 0.288284
# epoch 79/2000; train loss: 0.3640, val_loss: 0.3872s: 0.288377
# epoch 80/2000; train loss: 0.3648, val_loss: 0.3870s: 0.288572
# epoch 81/2000; train loss: 0.3633, val_loss: 0.3858s: 0.288370
# epoch 82/2000; train loss: 0.3643, val_loss: 0.3856s: 0.288558
# epoch 83/2000; train loss: 0.3629, val_loss: 0.3850s: 0.288156
# epoch 84/2000; train loss: 0.3630, val_loss: 0.3843s: 0.288250
# epoch 85/2000; train loss: 0.3614, val_loss: 0.3844s: 0.287943
# epoch 86/2000; train loss: 0.3602, val_loss: 0.3833s: 0.287644
# epoch 87/2000; train loss: 0.3613, val_loss: 0.3849s: 0.288033
# epoch 88/2000; train loss: 0.3618, val_loss: 0.3827s: 0.287349
# epoch 89/2000; train loss: 0.3592, val_loss: 0.3824s: 0.287027
# epoch 90/2000; train loss: 0.3617, val_loss: 0.3825s: 0.287024
# epoch 91/2000; train loss: 0.3583, val_loss: 0.3813s: 0.286325
# epoch 92/2000; train loss: 0.3583, val_loss: 0.3809s: 0.286113
# epoch 93/2000; train loss: 0.3597, val_loss: 0.3808s: 0.286209
# epoch 94/2000; train loss: 0.3578, val_loss: 0.3800s: 0.285408
# epoch 95/2000; train loss: 0.3573, val_loss: 0.3796s: 0.285000
# epoch 96/2000; train loss: 0.3567, val_loss: 0.3795s: 0.284896
# epoch 97/2000; train loss: 0.3578, val_loss: 0.3786s: 0.284295
# epoch 98/2000; train loss: 0.3580, val_loss: 0.3784s: 0.284186
# epoch 99/2000; train loss: 0.3558, val_loss: 0.3779s: 0.283584
# epoch 100/2000; train loss: 0.3554, val_loss: 0.3783s: 0.283379
# epoch 101/2000; train loss: 0.3555, val_loss: 0.3772s: 0.282683
# epoch 102/2000; train loss: 0.3580, val_loss: 0.3811s: 0.284572
# epoch 103/2000; train loss: 0.3562, val_loss: 0.3765s: 0.282011
# epoch 104/2000; train loss: 0.3538, val_loss: 0.3768s: 0.281965
# epoch 105/2000; train loss: 0.3549, val_loss: 0.3758s: 0.281268
# epoch 106/2000; train loss: 0.3535, val_loss: 0.3760s: 0.281058
# epoch 107/2000; train loss: 0.3542, val_loss: 0.3749s: 0.280460
# epoch 108/2000; train loss: 0.3525, val_loss: 0.3749s: 0.280249
# epoch 109/2000; train loss: 0.3524, val_loss: 0.3751s: 0.280049
# epoch 110/2000; train loss: 0.3545, val_loss: 0.3748s: 0.279751
# epoch 111/2000; train loss: 0.3527, val_loss: 0.3753s: 0.280048
# epoch 112/2000; train loss: 0.3528, val_loss: 0.3738s: 0.278953
# epoch 113/2000; train loss: 0.3508, val_loss: 0.3734s: 0.278438
# epoch 114/2000; train loss: 0.3522, val_loss: 0.3731s: 0.278234
# epoch 115/2000; train loss: 0.3522, val_loss: 0.3735s: 0.278131
# epoch 116/2000; train loss: 0.3500, val_loss: 0.3725s: 0.277335
# epoch 117/2000; train loss: 0.3493, val_loss: 0.3731s: 0.277425
# epoch 118/2000; train loss: 0.3497, val_loss: 0.3723s: 0.276831
# epoch 119/2000; train loss: 0.3501, val_loss: 0.3711s: 0.276123
# epoch 120/2000; train loss: 0.3507, val_loss: 0.3702s: 0.275511
# epoch 121/2000; train loss: 0.3479, val_loss: 0.3708s: 0.275702
# epoch 122/2000; train loss: 0.3488, val_loss: 0.3691s: 0.274708
# epoch 123/2000; train loss: 0.3494, val_loss: 0.3697s: 0.275091
# epoch 124/2000; train loss: 0.3486, val_loss: 0.3691s: 0.274597
# epoch 125/2000; train loss: 0.3475, val_loss: 0.3698s: 0.275091
# epoch 126/2000; train loss: 0.3477, val_loss: 0.3678s: 0.273598
# epoch 127/2000; train loss: 0.3464, val_loss: 0.3689s: 0.274378
# epoch 128/2000; train loss: 0.3463, val_loss: 0.3668s: 0.272889
# epoch 129/2000; train loss: 0.3453, val_loss: 0.3705s: 0.274968
# epoch 130/2000; train loss: 0.3461, val_loss: 0.3691s: 0.273705
# epoch 131/2000; train loss: 0.3465, val_loss: 0.3678s: 0.273191
# epoch 132/2000; train loss: 0.3453, val_loss: 0.3687s: 0.274278
# epoch 133/2000; train loss: 0.3469, val_loss: 0.3685s: 0.273787
# epoch 134/2000; train loss: 0.3448, val_loss: 0.3654s: 0.271985
# epoch 135/2000; train loss: 0.3458, val_loss: 0.3675s: 0.273054
# epoch 136/2000; train loss: 0.3438, val_loss: 0.3657s: 0.271675
# epoch 137/2000; train loss: 0.3442, val_loss: 0.3654s: 0.271657
# epoch 138/2000; train loss: 0.3448, val_loss: 0.3648s: 0.271454
# epoch 139/2000; train loss: 0.3437, val_loss: 0.3668s: 0.272548
# epoch 140/2000; train loss: 0.3427, val_loss: 0.3642s: 0.270768
# epoch 141/2000; train loss: 0.3447, val_loss: 0.3710s: 0.275242
# epoch 142/2000; train loss: 0.3455, val_loss: 0.3672s: 0.272710
# epoch 143/2000; train loss: 0.3453, val_loss: 0.3661s: 0.272072
# epoch 144/2000; train loss: 0.3447, val_loss: 0.3640s: 0.270661
# epoch 145/2000; train loss: 0.3428, val_loss: 0.3628s: 0.269840
# epoch 146/2000; train loss: 0.3426, val_loss: 0.3635s: 0.270228
# epoch 147/2000; train loss: 0.3419, val_loss: 0.3637s: 0.270035
# epoch 148/2000; train loss: 0.3418, val_loss: 0.3627s: 0.269637
# epoch 149/2000; train loss: 0.3438, val_loss: 0.3642s: 0.270427
# epoch 150/2000; train loss: 0.3414, val_loss: 0.3636s: 0.269842
# epoch 151/2000; train loss: 0.3420, val_loss: 0.3633s: 0.269836
# epoch 152/2000; train loss: 0.3415, val_loss: 0.3635s: 0.269833
# epoch 153/2000; train loss: 0.3406, val_loss: 0.3638s: 0.269635
# epoch 154/2000; train loss: 0.3415, val_loss: 0.3618s: 0.268638
# epoch 155/2000; train loss: 0.3423, val_loss: 0.3640s: 0.269718
# epoch 156/2000; train loss: 0.3420, val_loss: 0.3623s: 0.268540
# epoch 157/2000; train loss: 0.3415, val_loss: 0.3630s: 0.269023
# epoch 158/2000; train loss: 0.3412, val_loss: 0.3623s: 0.268430
# epoch 159/2000; train loss: 0.3416, val_loss: 0.3632s: 0.269023
# epoch 160/2000; train loss: 0.3412, val_loss: 0.3620s: 0.268132
# epoch 161/2000; train loss: 0.3403, val_loss: 0.3611s: 0.267420
# epoch 162/2000; train loss: 0.3400, val_loss: 0.3606s: 0.267211
# epoch 163/2000; train loss: 0.3404, val_loss: 0.3644s: 0.269506
# epoch 164/2000; train loss: 0.3413, val_loss: 0.3615s: 0.267644
# epoch 165/2000; train loss: 0.3407, val_loss: 0.3626s: 0.268415
# epoch 166/2000; train loss: 0.3397, val_loss: 0.3619s: 0.267526
# epoch 167/2000; train loss: 0.3407, val_loss: 0.3606s: 0.266819
# epoch 168/2000; train loss: 0.3391, val_loss: 0.3618s: 0.267606
# epoch 169/2000; train loss: 0.3382, val_loss: 0.3619s: 0.267318
# epoch 170/2000; train loss: 0.3397, val_loss: 0.3610s: 0.266719
# epoch 171/2000; train loss: 0.3394, val_loss: 0.3615s: 0.266910
# epoch 172/2000; train loss: 0.3379, val_loss: 0.3594s: 0.265515
# epoch 173/2000; train loss: 0.3388, val_loss: 0.3598s: 0.265994
# epoch 174/2000; train loss: 0.3399, val_loss: 0.3591s: 0.265398
# epoch 175/2000; train loss: 0.3389, val_loss: 0.3630s: 0.268191
# epoch 176/2000; train loss: 0.3388, val_loss: 0.3602s: 0.265430
# epoch 177/2000; train loss: 0.3394, val_loss: 0.3588s: 0.265102
# epoch 178/2000; train loss: 0.3379, val_loss: 0.3584s: 0.264488
# epoch 179/2000; train loss: 0.3387, val_loss: 0.3602s: 0.265384
# epoch 180/2000; train loss: 0.3392, val_loss: 0.3599s: 0.265502
# epoch 181/2000; train loss: 0.3362, val_loss: 0.3579s: 0.263899
# epoch 182/2000; train loss: 0.3391, val_loss: 0.3609s: 0.266079
# epoch 183/2000; train loss: 0.3381, val_loss: 0.3593s: 0.264509
# epoch 184/2000; train loss: 0.3380, val_loss: 0.3573s: 0.263493
# epoch 185/2000; train loss: 0.3373, val_loss: 0.3577s: 0.263473
# epoch 186/2000; train loss: 0.3370, val_loss: 0.3583s: 0.263777
# epoch 187/2000; train loss: 0.3359, val_loss: 0.3583s: 0.263783
# epoch 188/2000; train loss: 0.3359, val_loss: 0.3574s: 0.262783
# epoch 189/2000; train loss: 0.3366, val_loss: 0.3587s: 0.263874
# epoch 190/2000; train loss: 0.3353, val_loss: 0.3576s: 0.262787
# epoch 191/2000; train loss: 0.3379, val_loss: 0.3568s: 0.261976
# epoch 192/2000; train loss: 0.3371, val_loss: 0.3563s: 0.262568
# epoch 193/2000; train loss: 0.3347, val_loss: 0.3576s: 0.262363
# epoch 194/2000; train loss: 0.3357, val_loss: 0.3569s: 0.262076
# epoch 195/2000; train loss: 0.3361, val_loss: 0.3564s: 0.261569
# epoch 196/2000; train loss: 0.3354, val_loss: 0.3554s: 0.260964
# epoch 197/2000; train loss: 0.3340, val_loss: 0.3552s: 0.260454
# epoch 198/2000; train loss: 0.3361, val_loss: 0.3544s: 0.260052
# epoch 199/2000; train loss: 0.3341, val_loss: 0.3599s: 0.263544
# epoch 200/2000; train loss: 0.3349, val_loss: 0.3570s: 0.261799
# epoch 201/2000; train loss: 0.3355, val_loss: 0.3548s: 0.260170
# epoch 202/2000; train loss: 0.3338, val_loss: 0.3543s: 0.259248
# epoch 203/2000; train loss: 0.3350, val_loss: 0.3558s: 0.260743
# epoch 204/2000; train loss: 0.3347, val_loss: 0.3589s: 0.262658
# epoch 205/2000; train loss: 0.3334, val_loss: 0.3541s: 0.258789
# epoch 206/2000; train loss: 0.3343, val_loss: 0.3537s: 0.258541
# epoch 207/2000; train loss: 0.3343, val_loss: 0.3537s: 0.258837
# epoch 208/2000; train loss: 0.3338, val_loss: 0.3526s: 0.257737
# epoch 209/2000; train loss: 0.3351, val_loss: 0.3537s: 0.258826
# epoch 210/2000; train loss: 0.3343, val_loss: 0.3536s: 0.258037
# epoch 211/2000; train loss: 0.3335, val_loss: 0.3519s: 0.257036
# epoch 212/2000; train loss: 0.3335, val_loss: 0.3536s: 0.258019
# epoch 213/2000; train loss: 0.3315, val_loss: 0.3536s: 0.258036
# epoch 214/2000; train loss: 0.3319, val_loss: 0.3529s: 0.257136
# epoch 215/2000; train loss: 0.3333, val_loss: 0.3551s: 0.258329
# epoch 216/2000; train loss: 0.3331, val_loss: 0.3509s: 0.256151
# epoch 217/2000; train loss: 0.3316, val_loss: 0.3512s: 0.255909
# epoch 218/2000; train loss: 0.3301, val_loss: 0.3505s: 0.255312
# epoch 219/2000; train loss: 0.3310, val_loss: 0.3507s: 0.256005
# epoch 220/2000; train loss: 0.3303, val_loss: 0.3520s: 0.255907
# epoch 221/2000; train loss: 0.3321, val_loss: 0.3522s: 0.256620
# epoch 222/2000; train loss: 0.3304, val_loss: 0.3509s: 0.255222
# epoch 223/2000; train loss: 0.3319, val_loss: 0.3493s: 0.254209
# epoch 224/2000; train loss: 0.3300, val_loss: 0.3489s: 0.254093
# epoch 225/2000; train loss: 0.3303, val_loss: 0.3497s: 0.254289
# epoch 226/2000; train loss: 0.3298, val_loss: 0.3525s: 0.255597
# epoch 227/2000; train loss: 0.3295, val_loss: 0.3493s: 0.253725
# epoch 228/2000; train loss: 0.3291, val_loss: 0.3508s: 0.254793
# epoch 229/2000; train loss: 0.3310, val_loss: 0.3494s: 0.254208
# epoch 230/2000; train loss: 0.3295, val_loss: 0.3489s: 0.253694
# epoch 231/2000; train loss: 0.3288, val_loss: 0.3483s: 0.252589
# epoch 232/2000; train loss: 0.3305, val_loss: 0.3512s: 0.254483
# epoch 233/2000; train loss: 0.3299, val_loss: 0.3474s: 0.252012
# epoch 234/2000; train loss: 0.3282, val_loss: 0.3473s: 0.252174
# epoch 235/2000; train loss: 0.3296, val_loss: 0.3473s: 0.251673
# epoch 236/2000; train loss: 0.3293, val_loss: 0.3480s: 0.252173
# epoch 237/2000; train loss: 0.3291, val_loss: 0.3475s: 0.251580
# epoch 238/2000; train loss: 0.3279, val_loss: 0.3467s: 0.250975
# epoch 239/2000; train loss: 0.3278, val_loss: 0.3457s: 0.250367
# epoch 240/2000; train loss: 0.3267, val_loss: 0.3461s: 0.250457
# epoch 241/2000; train loss: 0.3269, val_loss: 0.3478s: 0.251161
# epoch 242/2000; train loss: 0.3273, val_loss: 0.3460s: 0.250078
# epoch 243/2000; train loss: 0.3269, val_loss: 0.3466s: 0.250160
# epoch 244/2000; train loss: 0.3272, val_loss: 0.3448s: 0.249066
# epoch 245/2000; train loss: 0.3281, val_loss: 0.3477s: 0.250648
# epoch 246/2000; train loss: 0.3266, val_loss: 0.3446s: 0.248277
# epoch 247/2000; train loss: 0.3272, val_loss: 0.3445s: 0.247946
# epoch 248/2000; train loss: 0.3267, val_loss: 0.3473s: 0.250345
# epoch 249/2000; train loss: 0.3263, val_loss: 0.3465s: 0.248773
# epoch 250/2000; train loss: 0.3266, val_loss: 0.3468s: 0.249065
# epoch 251/2000; train loss: 0.3268, val_loss: 0.3443s: 0.247068
# epoch 252/2000; train loss: 0.3251, val_loss: 0.3434s: 0.246243
# epoch 253/2000; train loss: 0.3264, val_loss: 0.3433s: 0.246234
# epoch 254/2000; train loss: 0.3253, val_loss: 0.3424s: 0.245333
# epoch 255/2000; train loss: 0.3250, val_loss: 0.3454s: 0.247224
# epoch 256/2000; train loss: 0.3274, val_loss: 0.3441s: 0.246354
# epoch 257/2000; train loss: 0.3256, val_loss: 0.3446s: 0.245641
# epoch 258/2000; train loss: 0.3255, val_loss: 0.3429s: 0.244546
# epoch 259/2000; train loss: 0.3241, val_loss: 0.3459s: 0.246929
# epoch 260/2000; train loss: 0.3252, val_loss: 0.3435s: 0.245059
# epoch 261/2000; train loss: 0.3231, val_loss: 0.3422s: 0.243835
# epoch 262/2000; train loss: 0.3243, val_loss: 0.3411s: 0.242822
# epoch 263/2000; train loss: 0.3226, val_loss: 0.3417s: 0.243111
# epoch 264/2000; train loss: 0.3236, val_loss: 0.3432s: 0.244617
# epoch 265/2000; train loss: 0.3230, val_loss: 0.3419s: 0.243132
# epoch 266/2000; train loss: 0.3236, val_loss: 0.3416s: 0.242919
# epoch 267/2000; train loss: 0.3231, val_loss: 0.3395s: 0.241616
# epoch 268/2000; train loss: 0.3231, val_loss: 0.3404s: 0.241895
# epoch 269/2000; train loss: 0.3229, val_loss: 0.3398s: 0.241404
# epoch 270/2000; train loss: 0.3236, val_loss: 0.3400s: 0.241798
# epoch 271/2000; train loss: 0.3246, val_loss: 0.3450s: 0.244800
# epoch 272/2000; train loss: 0.3241, val_loss: 0.3399s: 0.241750
# epoch 273/2000; train loss: 0.3223, val_loss: 0.3406s: 0.241799
# epoch 274/2000; train loss: 0.3231, val_loss: 0.3426s: 0.242606
# epoch 275/2000; train loss: 0.3227, val_loss: 0.3389s: 0.240526
# epoch 276/2000; train loss: 0.3233, val_loss: 0.3381s: 0.239989
# epoch 277/2000; train loss: 0.3227, val_loss: 0.3385s: 0.240281
# epoch 278/2000; train loss: 0.3220, val_loss: 0.3408s: 0.241285
# epoch 279/2000; train loss: 0.3224, val_loss: 0.3393s: 0.240308
# epoch 280/2000; train loss: 0.3211, val_loss: 0.3393s: 0.240893
# epoch 281/2000; train loss: 0.3230, val_loss: 0.3389s: 0.239993
# epoch 282/2000; train loss: 0.3216, val_loss: 0.3398s: 0.240689
# epoch 283/2000; train loss: 0.3210, val_loss: 0.3377s: 0.239798
# epoch 284/2000; train loss: 0.3215, val_loss: 0.3379s: 0.239777
# epoch 285/2000; train loss: 0.3216, val_loss: 0.3394s: 0.240079
# epoch 286/2000; train loss: 0.3208, val_loss: 0.3379s: 0.239694
# epoch 287/2000; train loss: 0.3224, val_loss: 0.3398s: 0.240479
# epoch 288/2000; train loss: 0.3210, val_loss: 0.3390s: 0.240298
# epoch 289/2000; train loss: 0.3215, val_loss: 0.3362s: 0.238390
# epoch 290/2000; train loss: 0.3219, val_loss: 0.3366s: 0.238662
# epoch 291/2000; train loss: 0.3210, val_loss: 0.3375s: 0.238866
# epoch 292/2000; train loss: 0.3201, val_loss: 0.3364s: 0.238275
# epoch 293/2000; train loss: 0.3211, val_loss: 0.3362s: 0.238564
# epoch 294/2000; train loss: 0.3206, val_loss: 0.3363s: 0.238262
# epoch 295/2000; train loss: 0.3206, val_loss: 0.3375s: 0.238963
# epoch 296/2000; train loss: 0.3203, val_loss: 0.3365s: 0.238375
# epoch 297/2000; train loss: 0.3208, val_loss: 0.3374s: 0.239065
# epoch 298/2000; train loss: 0.3217, val_loss: 0.3354s: 0.237774
# epoch 299/2000; train loss: 0.3207, val_loss: 0.3388s: 0.239754
# epoch 300/2000; train loss: 0.3208, val_loss: 0.3374s: 0.239288
# epoch 301/2000; train loss: 0.3211, val_loss: 0.3375s: 0.239174
# epoch 302/2000; train loss: 0.3200, val_loss: 0.3365s: 0.238175
# epoch 303/2000; train loss: 0.3209, val_loss: 0.3368s: 0.238665
# epoch 304/2000; train loss: 0.3207, val_loss: 0.3355s: 0.237868
# epoch 305/2000; train loss: 0.3195, val_loss: 0.3358s: 0.237455
# epoch 306/2000; train loss: 0.3197, val_loss: 0.3377s: 0.238658
# epoch 307/2000; train loss: 0.3194, val_loss: 0.3354s: 0.237477
# epoch 308/2000; train loss: 0.3195, val_loss: 0.3345s: 0.236754
# epoch 309/2000; train loss: 0.3207, val_loss: 0.3346s: 0.236745
# epoch 310/2000; train loss: 0.3191, val_loss: 0.3353s: 0.237346
# epoch 311/2000; train loss: 0.3195, val_loss: 0.3348s: 0.236853
# epoch 312/2000; train loss: 0.3190, val_loss: 0.3360s: 0.238048
# epoch 313/2000; train loss: 0.3199, val_loss: 0.3353s: 0.237460
# epoch 314/2000; train loss: 0.3200, val_loss: 0.3340s: 0.236953
# epoch 315/2000; train loss: 0.3189, val_loss: 0.3354s: 0.237340
# epoch 316/2000; train loss: 0.3207, val_loss: 0.3363s: 0.238454
# epoch 317/2000; train loss: 0.3198, val_loss: 0.3339s: 0.236363
# epoch 318/2000; train loss: 0.3182, val_loss: 0.3336s: 0.236139
# epoch 319/2000; train loss: 0.3197, val_loss: 0.3337s: 0.236236
# epoch 320/2000; train loss: 0.3177, val_loss: 0.3340s: 0.236337
# epoch 321/2000; train loss: 0.3199, val_loss: 0.3333s: 0.235740
# epoch 322/2000; train loss: 0.3208, val_loss: 0.3359s: 0.237833
# epoch 323/2000; train loss: 0.3189, val_loss: 0.3360s: 0.237859
# epoch 324/2000; train loss: 0.3182, val_loss: 0.3347s: 0.237160
# epoch 325/2000; train loss: 0.3190, val_loss: 0.3345s: 0.236647
# epoch 326/2000; train loss: 0.3197, val_loss: 0.3335s: 0.235745
# epoch 327/2000; train loss: 0.3198, val_loss: 0.3338s: 0.235835
# epoch 328/2000; train loss: 0.3194, val_loss: 0.3334s: 0.235738
# epoch 329/2000; train loss: 0.3183, val_loss: 0.3320s: 0.234834
# epoch 330/2000; train loss: 0.3189, val_loss: 0.3368s: 0.238720
# epoch 331/2000; train loss: 0.3188, val_loss: 0.3319s: 0.235068
# epoch 332/2000; train loss: 0.3179, val_loss: 0.3331s: 0.235719
# epoch 333/2000; train loss: 0.3186, val_loss: 0.3321s: 0.234931
# epoch 334/2000; train loss: 0.3184, val_loss: 0.3322s: 0.234821
# epoch 335/2000; train loss: 0.3197, val_loss: 0.3375s: 0.238522
# epoch 336/2000; train loss: 0.3191, val_loss: 0.3317s: 0.234675
# epoch 337/2000; train loss: 0.3188, val_loss: 0.3366s: 0.238717
# epoch 338/2000; train loss: 0.3181, val_loss: 0.3324s: 0.234966
# epoch 339/2000; train loss: 0.3176, val_loss: 0.3313s: 0.234424
# epoch 340/2000; train loss: 0.3177, val_loss: 0.3314s: 0.234513
# epoch 341/2000; train loss: 0.3175, val_loss: 0.3329s: 0.235514
# epoch 342/2000; train loss: 0.3179, val_loss: 0.3327s: 0.235329
# epoch 343/2000; train loss: 0.3184, val_loss: 0.3323s: 0.235027
# epoch 344/2000; train loss: 0.3171, val_loss: 0.3314s: 0.234423
# epoch 345/2000; train loss: 0.3172, val_loss: 0.3318s: 0.234714
# epoch 346/2000; train loss: 0.3170, val_loss: 0.3308s: 0.234218
# epoch 347/2000; train loss: 0.3176, val_loss: 0.3308s: 0.234008
# epoch 348/2000; train loss: 0.3169, val_loss: 0.3308s: 0.234208
# epoch 349/2000; train loss: 0.3179, val_loss: 0.3350s: 0.237308
# epoch 350/2000; train loss: 0.3181, val_loss: 0.3316s: 0.234450
# epoch 351/2000; train loss: 0.3181, val_loss: 0.3343s: 0.236516
# epoch 352/2000; train loss: 0.3186, val_loss: 0.3315s: 0.234743
# epoch 353/2000; train loss: 0.3170, val_loss: 0.3316s: 0.234415
# epoch 354/2000; train loss: 0.3171, val_loss: 0.3310s: 0.234116
# epoch 355/2000; train loss: 0.3174, val_loss: 0.3300s: 0.233610
# epoch 356/2000; train loss: 0.3160, val_loss: 0.3301s: 0.233400
# epoch 357/2000; train loss: 0.3173, val_loss: 0.3326s: 0.235601
# epoch 358/2000; train loss: 0.3175, val_loss: 0.3326s: 0.235126
# epoch 359/2000; train loss: 0.3161, val_loss: 0.3307s: 0.234026
# epoch 360/2000; train loss: 0.3176, val_loss: 0.3301s: 0.233507
# epoch 361/2000; train loss: 0.3170, val_loss: 0.3297s: 0.233301
# epoch 362/2000; train loss: 0.3164, val_loss: 0.3308s: 0.233997
# epoch 363/2000; train loss: 0.3158, val_loss: 0.3292s: 0.233208
# epoch 364/2000; train loss: 0.3167, val_loss: 0.3305s: 0.234492
# epoch 365/2000; train loss: 0.3169, val_loss: 0.3289s: 0.232805
# epoch 366/2000; train loss: 0.3172, val_loss: 0.3299s: 0.233389
# epoch 367/2000; train loss: 0.3163, val_loss: 0.3286s: 0.232799
# epoch 368/2000; train loss: 0.3162, val_loss: 0.3291s: 0.233086
# epoch 369/2000; train loss: 0.3160, val_loss: 0.3292s: 0.232991
# epoch 370/2000; train loss: 0.3166, val_loss: 0.3299s: 0.233492
# epoch 371/2000; train loss: 0.3162, val_loss: 0.3300s: 0.233599
# epoch 372/2000; train loss: 0.3158, val_loss: 0.3289s: 0.232800
# epoch 373/2000; train loss: 0.3166, val_loss: 0.3292s: 0.232989
# epoch 374/2000; train loss: 0.3155, val_loss: 0.3286s: 0.232692
# epoch 375/2000; train loss: 0.3156, val_loss: 0.3281s: 0.232486
# epoch 376/2000; train loss: 0.3154, val_loss: 0.3281s: 0.232381
# epoch 377/2000; train loss: 0.3155, val_loss: 0.3285s: 0.232681
# epoch 378/2000; train loss: 0.3160, val_loss: 0.3290s: 0.232985
# epoch 379/2000; train loss: 0.3162, val_loss: 0.3303s: 0.233590
# epoch 380/2000; train loss: 0.3158, val_loss: 0.3291s: 0.233003
# epoch 381/2000; train loss: 0.3152, val_loss: 0.3288s: 0.232891
# epoch 382/2000; train loss: 0.3161, val_loss: 0.3301s: 0.234988
# epoch 383/2000; train loss: 0.3158, val_loss: 0.3284s: 0.232401
# epoch 384/2000; train loss: 0.3155, val_loss: 0.3278s: 0.232284
# epoch 385/2000; train loss: 0.3158, val_loss: 0.3303s: 0.234078
# epoch 386/2000; train loss: 0.3152, val_loss: 0.3280s: 0.232303
# epoch 387/2000; train loss: 0.3148, val_loss: 0.3298s: 0.233280
# epoch 388/2000; train loss: 0.3161, val_loss: 0.3296s: 0.233298
# epoch 389/2000; train loss: 0.3153, val_loss: 0.3274s: 0.231896
# epoch 390/2000; train loss: 0.3164, val_loss: 0.3326s: 0.236474
# epoch 391/2000; train loss: 0.3156, val_loss: 0.3278s: 0.232126
# epoch 392/2000; train loss: 0.3155, val_loss: 0.3284s: 0.233078
# epoch 393/2000; train loss: 0.3150, val_loss: 0.3279s: 0.232484
# epoch 394/2000; train loss: 0.3152, val_loss: 0.3284s: 0.232579
# epoch 395/2000; train loss: 0.3172, val_loss: 0.3302s: 0.234284
# epoch 396/2000; train loss: 0.3147, val_loss: 0.3281s: 0.232802
# epoch 397/2000; train loss: 0.3154, val_loss: 0.3291s: 0.233981
# epoch 398/2000; train loss: 0.3145, val_loss: 0.3291s: 0.233791
# epoch 399/2000; train loss: 0.3151, val_loss: 0.3280s: 0.232391
# epoch 400/2000; train loss: 0.3148, val_loss: 0.3281s: 0.232380
# epoch 401/2000; train loss: 0.3153, val_loss: 0.3275s: 0.232681
# epoch 402/2000; train loss: 0.3153, val_loss: 0.3277s: 0.232275
# epoch 403/2000; train loss: 0.3151, val_loss: 0.3270s: 0.231677
# epoch 404/2000; train loss: 0.3140, val_loss: 0.3269s: 0.231870
# epoch 405/2000; train loss: 0.3151, val_loss: 0.3284s: 0.232669
# epoch 406/2000; train loss: 0.3145, val_loss: 0.3273s: 0.232084
# epoch 407/2000; train loss: 0.3156, val_loss: 0.3292s: 0.233073
# epoch 408/2000; train loss: 0.3151, val_loss: 0.3265s: 0.231592
# epoch 409/2000; train loss: 0.3147, val_loss: 0.3280s: 0.232465
# epoch 410/2000; train loss: 0.3148, val_loss: 0.3276s: 0.232280
# epoch 411/2000... 34/100: train loss: 0.3029, val_loss: 0.3276
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18764\95570909.py in <module>
#      44                        epochs=2000,
#      45                        dataloader=dl_deblur)
# ---> 46 history = trainer.train()
#
# ~\AppData\Local\Temp\ipykernel_18764\1813109920.py in train(self)
#      31                 preds = self.model(data).type(torch.FloatTensor)
#      32                 target = batch[1].to(device).type(torch.FloatTensor)
# ---> 33                 loss = self.criterion(preds, target)
#      34                 loss.backward()
#      35                 epoch_loss.append(loss.numpy(force=True))
#
# ~\AppData\Local\Temp\ipykernel_18764\95570909.py in loss_tv(y_pred, y_true)
#       9
#      10 def loss_tv(y_pred, y_true):
# ---> 11     loss = TVLoss()(y_pred)
#      12     loss = 10000/loss + 0.01*nn.L1Loss()(y_pred, y_true)
#      13     return loss
#
# C:\anaconda3\lib\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# C:\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# C:\anaconda3\lib\site-packages\piq\tv.py in forward(self, x)
#      97             Value of TV loss to be minimized.
#      98         """
# ---> 99         score = total_variation(x, reduction=self.reduction, norm_type=self.norm_type)
#     100         return score
#
# C:\anaconda3\lib\site-packages\piq\tv.py in total_variation(x, reduction, norm_type)
#      34     elif norm_type == 'l2':
#      35         w_variance = torch.sum(torch.pow(x[:, :, :, 1:] - x[:, :, :, :-1], 2), dim=[1, 2, 3])
# ---> 36         h_variance = torch.sum(torch.pow(x[:, :, 1:, :] - x[:, :, :-1, :], 2), dim=[1, 2, 3])
#      37         score = torch.sqrt(h_variance + w_variance)
#      38     elif norm_type == 'l2_squared':
#
# KeyboardInterrupt:

# %%
plot_history(history)

# %%
#test = images_lr[0]
test = read_image('out_before.png')
test = test[None, :]
model_deblur.eval()
with torch.no_grad():
    preds = model_deblur(test).type(torch.LongTensor)
img = preds[0].permute(1,2,0).detach()
to_save = (preds[0])/255.
torchvision.utils.save_image(to_save, 'out.png')
plt.imshow(img)

ref = images_hr[0]
ref = ref[None, :]
ssim_after = ssim(preds, ref, data_range=255)
ssim_before = ssim(test, ref, data_range=255)
print(ssim_after, ssim_before)
# Out:
# tensor(0.9195) tensor(0.9263)

# %%
torch.save(model_deblur, 'ssim09282_1000epochs')
torch.save({
            'epoch': 1000,
            'model_state_dict': model_deblur.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': criterion_deblur
            }, 'torch_ssim09282_1000epochs')

# %%
images_lr[0]
# Out:
# tensor([[[0.4980, 0.5686, 0.6078,  ..., 0.1961, 0.2039, 0.2078],
#          [0.4941, 0.5529, 0.5804,  ..., 0.2157, 0.2196, 0.2235],
#          [0.5059, 0.5529, 0.5725,  ..., 0.2706, 0.2824, 0.2941],
#          ...,
#          [0.9490, 0.9608, 0.9412,  ..., 0.2471, 0.2431, 0.2353],
#          [0.9608, 0.9490, 0.9255,  ..., 0.2431, 0.2431, 0.2353],
#          [0.9412, 0.9137, 0.9020,  ..., 0.2431, 0.2431, 0.2431]],
#
#         [[0.2549, 0.2941, 0.3020,  ..., 0.1529, 0.1529, 0.1529],
#          [0.2353, 0.2706, 0.2784,  ..., 0.1529, 0.1490, 0.1412],
#          [0.2235, 0.2510, 0.2627,  ..., 0.1686, 0.1686, 0.1725],
#          ...,
#          [0.5490, 0.5686, 0.5490,  ..., 0.1608, 0.1569, 0.1490],
#          [0.5608, 0.5529, 0.5333,  ..., 0.1608, 0.1569, 0.1529],
#          [0.5333, 0.5137, 0.5020,  ..., 0.1608, 0.1608, 0.1647]],
#
#         [[0.1451, 0.1725, 0.1843,  ..., 0.1412, 0.1451, 0.1529],
#          [0.1569, 0.1882, 0.1922,  ..., 0.1294, 0.1333, 0.1333],
#          [0.1647, 0.1922, 0.1961,  ..., 0.1373, 0.1451, 0.1569],
#          ...,
#          [0.1255, 0.1569, 0.1412,  ..., 0.1412, 0.1333, 0.1333],
#          [0.1529, 0.1490, 0.1294,  ..., 0.1412, 0.1373, 0.1294],
#          [0.1529, 0.1216, 0.1059,  ..., 0.1451, 0.1412, 0.1412]]])

# %%
images_lr[0][0].numpy().shape
# Out:
# (400, 700)

# %%
lr = images_lr_downscales[0][0].numpy()
hr = images_hr[0][0].numpy()

gy, gx = np.gradient(lr)
gnorm = np.sqrt(gx**2 + gy**2)
print(np.average(gnorm))

gy, gx = np.gradient(hr)
gnorm = np.sqrt(gx**2 + gy**2)
print(np.average(gnorm))
# Out:
# 21.01626905868889
# 10.95381203369981

# %%
lr = images_lr_downscales[0].type(torch.FloatTensor)
hr = images_hr[0].type(torch.FloatTensor)

gy, gx, gc = torch.gradient(lr)
gnorm = torch.sqrt(gx**2 + gy**2 + gc**2)
print(torch.mean(gnorm))

gy, gx, gc = np.gradient(hr)
gnorm = np.sqrt(gx**2 + gy**2 + gc**2)
print(np.average(gnorm))
# Out:
# tensor(40.4811)
# 34.710903

# %%
trainer.loss.grad

# %%
def dft_amp(img):
    fft_im = torch.fft.rfft( img, signal_ndim=2, onesided=False )
    fft_amp = fft_im[:,:,:,:,0]**2 + fft_im[:,:,:,:,1]**2
    return torch.sqrt(fft_amp)

dft_amp(images_lr[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14132\2002341215.py in <module>
#       4     return torch.sqrt(fft_amp)
#       5
# ----> 6 dft_amp(images_lr[0])
#
# ~\AppData\Local\Temp\ipykernel_14132\2002341215.py in dft_amp(img)
#       1 def dft_amp(img):
# ----> 2     fft_im = torch.fft.rfft( img, signal_ndim=2, onesided=False )
#       3     fft_amp = fft_im[:,:,:,:,0]**2 + fft_im[:,:,:,:,1]**2
#       4     return torch.sqrt(fft_amp)
#       5
#
# TypeError: fft_rfft() got an unexpected keyword argument 'signal_ndim'

# %%
torch.fft.rfft(images_hr[0]).shape
# Out:
# torch.Size([3, 800, 701])

# %%
def tensor2freq(x):
    # crop image patches
    patch_factor = 1
    _, _, h, w = x.shape
    assert h % patch_factor == 0 and w % patch_factor == 0, (
        'Patch factor should be divisible by image height and width')
    patch_list = []
    patch_h = h // patch_factor
    patch_w = w // patch_factor
    for i in range(patch_factor):
        for j in range(patch_factor):
            patch_list.append(x[:, :, i * patch_h:(i + 1) * patch_h, j * patch_w:(j + 1) * patch_w])

        # stack to patch tensor
    y = torch.stack(patch_list, 1)

    # perform 2D DFT (real-to-complex, orthonormalization)
    freq = torch.fft.fft2(y, norm='ortho')
    freq = torch.stack([freq.real, freq.imag], -1)
    
    return freq.mean()

# %%
test = images_lr[0]
test = test[None, :]
tensor2freq(test)
# Out:
# tensor(0.0721)

# %%
def getSharpness(images):
    sharpness_vals = []
    derivative_imgs = []
    for img in images:
        derivative = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
        derivative_imgs.append(derivative)
        sharpness_vals.append(cv2.norm(derivative))
    return derivative_imgs, sharpness_vals

# %%
images_np = np.array(images_lr[0])
a, b = getSharpness(images_np)

# %%
b
# Out:
# [924742.4838478008, 804595.2767317243, 728193.959805353]

# %%
a
# Out:
# [array([[   0.,  908.,  760., ...,  150.,  136.,    0.],
#         [   0.,  842.,  656., ...,  227.,  185.,    0.],
#         [   0.,  751.,  504., ...,  409.,  316.,    0.],
#         ...,
#         [   0., -190., -472., ...,  -66.,  -76.,    0.],
#         [   0., -343., -505., ...,  -78.,  -74.,    0.],
#         [   0., -388., -478., ...,  -80.,  -66.,    0.]]),
#  array([[   0.,  346.,   94., ...,  -16.,  -46.,    0.],
#         [   0.,  362.,  129., ...,   20.,   -4.,    0.],
#         [   0.,  410.,  196., ...,  150.,  141.,    0.],
#         ...,
#         [   0., -124., -482., ...,  -58.,  -70.,    0.],
#         [   0., -283., -510., ...,  -72.,  -65.,    0.],
#         [   0., -330., -486., ...,  -74.,  -54.,    0.]]),
#  array([[   0.,  276.,   24., ...,   74.,  100.,    0.],
#         [   0.,  278.,   15., ...,  134.,  152.,    0.],
#         [   0.,  309.,   18., ...,  307.,  312.,    0.],
#         ...,
#         [   0., -101., -523., ...,  -69.,  -76.,    0.],
#         [   0., -308., -626., ...,  -87.,  -91.,    0.],
#         [   0., -388., -624., ...,  -90.,  -92.,    0.]])]

# %%
torch_sobel = Sobel()

# %%
images_tensor = torch.FloatTensor(np.array(images_lr[:1]))
im_gr = torchvision.transforms.Grayscale()(images_tensor)
print(im_gr.shape)
derivs = torch_sobel(im_gr)
derivs
# Out:
# torch.Size([1, 1, 400, 700])
# tensor([[[[124.3786,  65.1107,  70.5449,  ...,  55.6721,  64.9517,  68.5075],
#           [110.8581,  22.6103,  26.8387,  ..., 168.0509, 195.4942, 243.8969],
#           [119.5695,  33.0675,  40.2347,  ..., 320.4005, 336.0049, 361.7405],
#           ...,
#           [ 73.6868,  53.7021, 105.2892,  ...,   0.8454,   4.0844,  14.1444],
#           [  1.1179,  93.7471, 108.4399,  ...,   2.1554,   7.5163,  18.8298],
#           [ 91.5316, 105.1587,  86.2123,  ...,   9.7318,  11.0912,  16.1775]]]])

# %%
torch.linalg.norm(derivs)
# Out:
# tensor(165562.7188)

# %%
loss_sobel(images_tensor, None)
# Out:
# tensor(165562.7188, device='cuda:0')

# %%
images_tensor = torch.FloatTensor(np.array(images_lr[0]))
blur = torchvision.transforms.GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 2.))(images_tensor)
plt.imshow(blur.T)
torchvision.utils.save_image(blur, 'test1_blur.png')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class Sobel(nn.Module):
    def __init__(self):
        super().__init__()
        self.filter = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=3, stride=1, padding=0, bias=False)

        Gx = torch.tensor([[2.0, 0.0, -2.0], [4.0, 0.0, -4.0], [2.0, 0.0, -2.0]])
        Gy = torch.tensor([[2.0, 4.0, 2.0], [0.0, 0.0, 0.0], [-2.0, -4.0, -2.0]])
        G = torch.cat([Gx.unsqueeze(0), Gy.unsqueeze(0)], 0)
        G = G.unsqueeze(1)
        self.filter.weight = nn.Parameter(G, requires_grad=True)

    def forward(self, img):
        x = self.filter(img)
        x = torch.mul(x, x)
        x = torch.sum(x, dim=1, keepdim=True)
        x = torch.sqrt(x)
        return x
    
def loss_sobel(y_pred, y_true):
    torch_sobel = Sobel()
    grayscale = torchvision.transforms.Grayscale()(y_pred)
    out = torch.linalg.norm(torch_sobel(grayscale))
    print(out)
    return 1/out

# %%
ignite.============
# Out:
# [tensor([[[[127, 145, 155,  ...,  50,  52,  53],
#           [126, 141, 148,  ...,  55,  56,  57],
#           [129, 141, 146,  ...,  69,  72,  75],
#           ...,
#           [242, 245, 240,  ...,  63,  62,  60],
#           [245, 242, 236,  ...,  62,  62,  60],
#           [240, 233, 230,  ...,  62,  62,  62]],
#
#          [[ 65,  75,  77,  ...,  39,  39,  39],
#           [ 60,  69,  71,  ...,  39,  38,  36],
#           [ 57,  64,  67,  ...,  43,  43,  44],
#           ...,
#           [140, 145, 140,  ...,  41,  40,  38],
#           [143, 141, 136,  ...,  41,  40,  39],
#           [136, 131, 128,  ...,  41,  41,  42]],
#
#          [[ 37,  44,  47,  ...,  36,  37,  39],
#           [ 40,  48,  49,  ...,  33,  34,  34],
#           [ 42,  49,  50,  ...,  35,  37,  40],
#           ...,
#           [ 32,  40,  36,  ...,  36,  34,  34],
#           [ 39,  38,  33,  ...,  36,  35,  33],
#           [ 39,  31,  27,  ...,  37,  36,  36]]]], dtype=torch.uint8), tensor([[[[127, 145, 155,  ...,  50,  52,  53],
#           [126, 141, 148,  ...,  55,  56,  57],
#           [129, 141, 146,  ...,  69,  72,  75],
#           ...,
#           [242, 245, 240,  ...,  63,  62,  60],
#           [245, 242, 236,  ...,  62,  62,  60],
#           [240, 233, 230,  ...,  62,  62,  62]],
#
#          [[ 65,  75,  77,  ...,  39,  39,  39],
#           [ 60,  69,  71,  ...,  39,  38,  36],
#           [ 57,  64,  67,  ...,  43,  43,  44],
#           ...,
#           [140, 145, 140,  ...,  41,  40,  38],
#           [143, 141, 136,  ...,  41,  40,  39],
#           [136, 131, 128,  ...,  41,  41,  42]],
#
#          [[ 37,  44,  47,  ...,  36,  37,  39],
#           [ 40,  48,  49,  ...,  33,  34,  34],
#           [ 42,  49,  50,  ...,  35,  37,  40],
#           ...,
#           [ 32,  40,  36,  ...,  36,  34,  34],
#           [ 39,  38,  33,  ...,  36,  35,  33],
#           [ 39,  31,  27,  ...,  37,  36,  36]]]], dtype=torch.uint8)]
