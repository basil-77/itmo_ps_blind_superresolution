# %%
import os

import numpy as np

import torch
import torchvision
from torchvision.io import read_image
from torchvision.transforms import v2

from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F

from piq import BRISQUELoss, TVLoss, brisque, ssim, psnr

import random

import cv2

import matplotlib.pyplot as plt

from utils import loss_history, plot_history

from tqdm import tqdm

import json

import wandb

import kornia

from torch_trainer import torch_trainer
import data
from hr2lr import hr2lr

# %matplotlib inline

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
class ChannelAttention(nn.Module):
    def __init__(self,channel,reduction=16):
        super().__init__()
        self.maxpool=nn.AdaptiveMaxPool2d(1)
        self.avgpool=nn.AdaptiveAvgPool2d(1)
        self.se=nn.Sequential(
            nn.Conv2d(channel,channel//reduction,1,bias=False),
            ##nn.ReLU(),
            nn.GELU(),
            nn.Conv2d(channel//reduction,channel,1,bias=False)
        )
        self.sigmoid=nn.Sigmoid()
    
    def forward(self, x) :
        max_result=self.maxpool(x)
        avg_result=self.avgpool(x)
        max_out=self.se(max_result)
        avg_out=self.se(avg_result)
        output=self.sigmoid(max_out+avg_out)
        return output

class SpatialAttention(nn.Module):
    def __init__(self,kernel_size=7):
        super().__init__()
        self.conv=nn.Conv2d(2,1,kernel_size=kernel_size,padding=kernel_size//2)
        self.sigmoid=nn.Sigmoid()
    
    def forward(self, x) :
        max_result,_=torch.max(x,dim=1,keepdim=True)
        avg_result=torch.mean(x,dim=1,keepdim=True)
        result=torch.cat([max_result,avg_result],1)
        output=self.conv(result)
        output=self.sigmoid(output)
        return output



class CBAMBlock(nn.Module):

    def __init__(self, channel=512,reduction=16,kernel_size=49):
        super().__init__()
        self.ca=ChannelAttention(channel=channel,reduction=reduction)
        self.sa=SpatialAttention(kernel_size=kernel_size)


    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                init.kaiming_normal_(m.weight, mode='fan_out')
                if m.bias is not None:
                    init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                init.constant_(m.weight, 1)
                init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                init.normal_(m.weight, std=0.001)
                if m.bias is not None:
                    init.constant_(m.bias, 0)

    def forward(self, x):
        b, c, _, _ = x.size()
        residual=x
        out=x*self.ca(x)
        out=out*self.sa(out)
        return out+residual

# %%
class conv_block(nn.Module):
    def __init__(self, activation=nn.GELU(), *args, **kwargs):
        super(conv_block, self).__init__()
        self.conv1 = nn.Conv2d(*args, **kwargs)
        #self.bn = nn.BatchNorm2d(kwargs['out_channels'])
        self.activation1 = activation
        self.conv2 = nn.Conv2d(*args, **kwargs)
        self.cbam = CBAMBlock(channel=kwargs['out_channels'])
        
    def forward(self, x):
        x_input = x
        x = self.conv1(x_input)
        #x = self.bn(x)
        x = self.activation1(x)
        x = self.conv2(x)
        x = self.cbam(x) + x_input
        return x
    
class sr_from_lr(nn.Module):
    def __init__(self, scale=2, n_blocks=8, channels=64, activation=nn.GELU(), activation_out=nn.Sigmoid()):
        super().__init__()
        
        self.n_blocks = n_blocks
        self.channels = channels
        self.scale = scale
        self.activation = activation
        self.activation_out = activation_out
               
        self.upscale = nn.Upsample(scale_factor=scale, mode='bicubic')
        
        self.conv_in = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=channels, kernel_size=3, padding='same'),
            #activation,
            #nn.Conv2d(in_channels=channels//6, out_channels=channels//4, kernel_size=3, padding='same'),
            #activation,
            #nn.Conv2d(in_channels=channels//4, out_channels=channels//2, kernel_size=3, padding='same'),
            #activation,
            #nn.Conv2d(in_channels=channels//2, out_channels=channels, kernel_size=3, padding='same'),
            #activation
            
        )
        
        self.conv_inner_blocks = nn.ModuleList(conv_block(activation=activation,
                                     in_channels=channels,
                                     out_channels=channels,
                                     kernel_size=3,
                                     padding='same') for n in range(n_blocks))
                
        self.conv_out = nn.Sequential(
            #nn.Conv2d(in_channels=channels, out_channels=channels//2, kernel_size=3, padding='same'),
            #activation,
            #nn.Conv2d(in_channels=channels//2, out_channels=channels//4, kernel_size=3, padding='same'),
            #activation,
            #nn.Conv2d(in_channels=channels//4, out_channels=channels//6, kernel_size=3, padding='same'),
            #activation,
            nn.Conv2d(in_channels=channels, out_channels=3, kernel_size=3, padding='same'),
        )
        
    
    def forward(self, x):
        x = self.upscale(x)
        x = self.conv_in(x)        
        for conv_inner in self.conv_inner_blocks:
            x = conv_inner(x)
        x = self.conv_out(x)
        if self.activation_out:
            x = self.activation_out(x)
        return x

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print (device)
# Out:
# cuda

# %% [markdown]
# # patches

# %%
ds_realsr_lr_patches = data.data_patches_realsr_x2_train(patch_size=(256,256))
ds_train_patches, ds_val_patches = torch.utils.data.random_split(ds_realsr_lr_patches, [0.8, 0.2])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 406/406 [00:16<00:00, 24.50it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 406/406 [00:11<00:00, 35.25it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 406/406 [00:48<00:00,  8.32it/s]

# %%
BATCH_SIZE = 2

dl_train_patches = DataLoader(ds_train_patches, batch_size=BATCH_SIZE, shuffle=True)
dl_val_patches = DataLoader(ds_val_patches, batch_size=1, shuffle=False)
dl_lr_patches = {'train': dl_train_patches, 'test': dl_val_patches}

# %%
scale = 2

kernel = torch.tensor(
        [
            [
                [1.0, 4.0, 6.0, 4.0, 1.0],
                [4.0, 16.0, 24.0, 16.0, 4.0],
                [6.0, 24.0, 36.0, 24.0, 6.0],
                [4.0, 16.0, 24.0, 16.0, 4.0],
                [1.0, 4.0, 6.0, 4.0, 1.0],
            ]
        ]
    )/ 256.0

kernel = kernel.to(device)
noise = (0., 0.02)

def loss_ssim_l2(y_pred, y_true, eps=1e-5):
    y_pred_down = hr2lr(img=y_pred, kernel=kernel, noise=noise, factor=scale)
    loss_ssim = kornia.losses.ssim_loss(y_pred_down, y_true, window_size=11, max_val=1.)
    loss_l2 = nn.MSELoss()(y_pred_down, y_true)
    loss_tv = kornia.losses.total_variation(y_pred, reduction='mean').sum()
    del y_true
    del y_pred_down
    torchvision.utils.save_image(y_pred[0], './run/v3_pred.png')
    del y_pred
    return 0.1*loss_l2 + 0.8*loss_ssim  + 0.1*loss_tv #+ 1./loss_tv


def metric_ssim(y_pred, y_true):
    y_pred_down = hr2lr(img=y_pred, kernel=kernel, noise=noise, factor=scale)
    return kornia.metrics.ssim(y_pred_down, y_true, window_size=11, max_val=1.).mean()

torch.cuda.empty_cache()
model = sr_from_lr(scale=scale, n_blocks=5, channels=128).to(device)
print(model)
criterion = loss_ssim_l2
optimizer = torch.optim.Adamax(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',factor=0.5, patience=3,min_lr=1e-10)
trainer = torch_trainer(model=model,
                       criterion=criterion,
                       optimizer=optimizer,
                       scheduler=scheduler, 
                       epochs=80,
                       dataloader=dl_lr_patches)
trainer.set_metrics(metric_name='SSIM', metric_function=metric_ssim)
#trainer.wandb_log(True)

#run = wandb.init(project='itmo blind superresolution', 
#                 group='v2_realsr_zssr', 
#                 job_type='train')
#wandb.watch(model, criterion, log="all", log_freq=10)

history = trainer.train()
# Out:
# sr_from_lr(
#   (activation): GELU(approximate='none')
#   (activation_out): Sigmoid()
#   (upscale): Upsample(scale_factor=2.0, mode='bicubic')
#   (conv_in): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   )
#   (conv_inner_blocks): ModuleList(
#     (0-4): 5 x conv_block(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (activation1): GELU(approximate='none')
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (cbam): CBAMBlock(
#         (ca): ChannelAttention(
#           (maxpool): AdaptiveMaxPool2d(output_size=1)
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (se): Sequential(
#             (0): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): GELU(approximate='none')
#             (2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv): Conv2d(2, 1, kernel_size=(49, 49), stride=(1, 1), padding=(24, 24))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (conv_out): Sequential(
#     (0): Conv2d(128, 3, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   )
# )
# epoch 1/80...  train/loss: 0.0380 val/loss: 0.0185 lr: 0.001 metric/SSIM: 0.9718; time: 000:05:48
# epoch 2/80...  train/loss: 0.0262 val/loss: 0.0189 lr: 0.001 metric/SSIM: 0.9707; time: 000:06:03
# epoch 3/80...  train/loss: 0.0242 val/loss: 0.0155 lr: 0.001 metric/SSIM: 0.9794; time: 000:06:11
# epoch 4/80...  train/loss: 0.0242 val/loss: 0.0174 lr: 0.001 metric/SSIM: 0.9746; time: 000:06:06
# epoch 5/80...  train/loss: 0.0234 val/loss: 0.0153 lr: 0.001 metric/SSIM: 0.9800; time: 000:06:15
# epoch 6/80...  train/loss: 0.0221 val/loss: 0.0151 lr: 0.001 metric/SSIM: 0.9799; time: 000:06:14
# epoch 7/80...  train/loss: 0.0235 val/loss: 0.0159 lr: 0.001 metric/SSIM: 0.9785; time: 000:06:34
# epoch 8/80...  train/loss: 0.0224 val/loss: 0.0146 lr: 0.001 metric/SSIM: 0.9815; time: 000:06:36
# epoch 9/80...  train/loss: 0.0216 val/loss: 0.0165 lr: 0.001 metric/SSIM: 0.9767; time: 000:06:47
# epoch 10/80...  train/loss: 0.0222 val/loss: 0.0167 lr: 0.001 metric/SSIM: 0.9766; time: 000:06:29
# epoch 11/80...  train/loss: 0.0216 val/loss: 0.0148 lr: 0.001 metric/SSIM: 0.9813; time: 000:06:27
# epoch 12/80...  train/loss: 0.0217 val/loss: 0.0147 lr: 0.001 metric/SSIM: 0.9814; time: 000:06:29
# epoch 13/80...  train/loss: 0.0218 val/loss: 0.0142 lr: 0.001 metric/SSIM: 0.9828; time: 000:06:36
# epoch 14/80...  train/loss: 0.0217 val/loss: 0.0143 lr: 0.001 metric/SSIM: 0.9828; time: 000:06:38
# epoch 15/80...  train/loss: 0.0215 val/loss: 0.0157 lr: 0.001 metric/SSIM: 0.9787; time: 000:06:26
# epoch 16/80...  train/loss: 0.0213 val/loss: 0.0142 lr: 0.001 metric/SSIM: 0.9836; time: 000:06:26
# epoch 17/80...  train/loss: 0.0218 val/loss: 0.0151 lr: 0.001 metric/SSIM: 0.9802; time: 000:06:28
# epoch 18/80...  train/loss: 0.0214 val/loss: 0.0144 lr: 0.001 metric/SSIM: 0.9821; time: 000:06:22
# epoch 19/80...  train/loss: 0.0213 val/loss: 0.0136 lr: 0.001 metric/SSIM: 0.9838; time: 000:06:21
# epoch 20/80...  train/loss: 0.0212 val/loss: 0.0140 lr: 0.001 metric/SSIM: 0.9832; time: 000:06:15
# epoch 21/80...  train/loss: 0.0207 val/loss: 0.0149 lr: 0.001 metric/SSIM: 0.9804; time: 000:06:24
# epoch 22/80...  train/loss: 0.0205 val/loss: 0.0137 lr: 0.001 metric/SSIM: 0.9835; time: 000:06:18
# epoch 23/80...  train/loss: 0.0205 val/loss: 0.0133 lr: 0.001 metric/SSIM: 0.9849; time: 000:06:24
# epoch 24/80...  train/loss: 0.0211 val/loss: 0.0147 lr: 0.001 metric/SSIM: 0.9811; time: 000:06:13
# epoch 25/80...  train/loss: 0.0211 val/loss: 0.0131 lr: 0.001 metric/SSIM: 0.9848; time: 000:06:19
# epoch 26/80...  train/loss: 0.0205 val/loss: 0.0130 lr: 0.001 metric/SSIM: 0.9852; time: 000:06:29
# epoch 27/80...  train/loss: 0.0204 val/loss: 0.0132 lr: 0.001 metric/SSIM: 0.9846; time: 000:06:20
# epoch 28/80...  train/loss: 0.0201 val/loss: 0.0149 lr: 0.001 metric/SSIM: 0.9807; time: 000:06:37
# epoch 29/80...  train/loss: 0.0204 val/loss: 0.0140 lr: 0.001 metric/SSIM: 0.9828; time: 000:06:30
# epoch 30/80...  train/loss: 0.0205 val/loss: 0.0141 lr: 0.001 metric/SSIM: 0.9821; time: 000:06:19
# epoch 31/80...  train/loss: 0.0203 val/loss: 0.0139 lr: 0.001 metric/SSIM: 0.9819; time: 000:06:20
# epoch 32/80...  train/loss: 0.0202 val/loss: 0.0133 lr: 0.0005 metric/SSIM: 0.9837; time: 000:06:23
# epoch 33/80...  train/loss: 0.0194 val/loss: 0.0130 lr: 0.0005 metric/SSIM: 0.9846; time: 000:06:13
# epoch 34/80...  train/loss: 0.0193 val/loss: 0.0130 lr: 0.0005 metric/SSIM: 0.9845; time: 000:06:19
# epoch 35/80...  train/loss: 0.0193 val/loss: 0.0128 lr: 0.0005 metric/SSIM: 0.9849; time: 000:06:14
# epoch 36/80...  train/loss: 0.0192 val/loss: 0.0130 lr: 0.0005 metric/SSIM: 0.9850; time: 000:06:14
# epoch 37/80...  train/loss: 0.0193 val/loss: 0.0128 lr: 0.0005 metric/SSIM: 0.9852; time: 000:06:18
# epoch 38/80...  train/loss: 0.0193 val/loss: 0.0127 lr: 0.0005 metric/SSIM: 0.9853; time: 000:06:18
# epoch 39/80...  train/loss: 0.0194 val/loss: 0.0132 lr: 0.0005 metric/SSIM: 0.9839; time: 000:06:14
# epoch 40/80...  train/loss: 0.0193 val/loss: 0.0129 lr: 0.00025 metric/SSIM: 0.9843; time: 000:06:16
# epoch 41/80...  train/loss: 0.0190 val/loss: 0.0125 lr: 0.00025 metric/SSIM: 0.9857; time: 000:06:13
# epoch 42/80...  train/loss: 0.0190 val/loss: 0.0125 lr: 0.00025 metric/SSIM: 0.9855; time: 000:06:16
# epoch 43/80...  train/loss: 0.0190 val/loss: 0.0130 lr: 0.00025 metric/SSIM: 0.9844; time: 000:06:34
# epoch 44/80...  train/loss: 0.0190 val/loss: 0.0127 lr: 0.00025 metric/SSIM: 0.9851; time: 000:06:32
# epoch 45/80...  train/loss: 0.0190 val/loss: 0.0125 lr: 0.00025 metric/SSIM: 0.9856; time: 000:06:35
# epoch 46/80...  train/loss: 0.0190 val/loss: 0.0126 lr: 0.000125 metric/SSIM: 0.9853; time: 000:06:31
# epoch 47/80...  train/loss: 0.0189 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9854; time: 000:06:32
# epoch 48/80...  train/loss: 0.0189 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9852; time: 000:06:31
# epoch 49/80...  train/loss: 0.0188 val/loss: 0.0126 lr: 0.000125 metric/SSIM: 0.9849; time: 000:06:35
# epoch 50/80...  train/loss: 0.0188 val/loss: 0.0126 lr: 0.000125 metric/SSIM: 0.9853; time: 000:07:06
# epoch 51/80...  train/loss: 0.0188 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9855; time: 000:07:18
# epoch 52/80...  train/loss: 0.0188 val/loss: 0.0126 lr: 0.000125 metric/SSIM: 0.9852; time: 000:07:27
# epoch 53/80...  train/loss: 0.0188 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9854; time: 000:07:07
# epoch 54/80...  train/loss: 0.0188 val/loss: 0.0126 lr: 0.000125 metric/SSIM: 0.9854; time: 000:07:35
# epoch 55/80...  train/loss: 0.0188 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9853; time: 000:07:38
# epoch 56/80...  train/loss: 0.0188 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9852; time: 000:07:51
# epoch 57/80...  train/loss: 0.0188 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9855; time: 000:07:43
# epoch 58/80...  train/loss: 0.0188 val/loss: 0.0124 lr: 0.000125 metric/SSIM: 0.9855; time: 000:07:50
# epoch 59/80...  train/loss: 0.0188 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9855; time: 000:07:53
# epoch 60/80...  train/loss: 0.0188 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9854; time: 000:07:48
# epoch 61/80...  train/loss: 0.0188 val/loss: 0.0124 lr: 0.000125 metric/SSIM: 0.9857; time: 000:08:10
# epoch 62/80...  train/loss: 0.0188 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9855; time: 000:07:47
# epoch 63/80...  train/loss: 0.0187 val/loss: 0.0124 lr: 0.000125 metric/SSIM: 0.9856; time: 000:06:57
# epoch 64/80...  train/loss: 0.0188 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9853; time: 000:06:48
# epoch 65/80...  train/loss: 0.0187 val/loss: 0.0124 lr: 0.000125 metric/SSIM: 0.9857; time: 000:06:39
# epoch 66/80...  train/loss: 0.0187 val/loss: 0.0124 lr: 0.000125 metric/SSIM: 0.9854; time: 000:06:35
# epoch 67/80...  train/loss: 0.0187 val/loss: 0.0124 lr: 0.000125 metric/SSIM: 0.9857; time: 000:07:33
# epoch 68/80...  train/loss: 0.0187 val/loss: 0.0124 lr: 0.000125 metric/SSIM: 0.9856; time: 000:07:34
# epoch 69/80...  train/loss: 0.0187 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9854; time: 000:07:22
# epoch 70/80...  train/loss: 0.0187 val/loss: 0.0124 lr: 0.000125 metric/SSIM: 0.9857; time: 000:07:17
# epoch 71/80...  train/loss: 0.0187 val/loss: 0.0123 lr: 0.000125 metric/SSIM: 0.9858; time: 000:07:18
# epoch 72/80...  train/loss: 0.0187 val/loss: 0.0124 lr: 0.000125 metric/SSIM: 0.9855; time: 000:07:30
# epoch 73/80...  train/loss: 0.0187 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9852; time: 000:07:37
# epoch 74/80...  train/loss: 0.0187 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9852; time: 000:07:37
# epoch 75/80...  train/loss: 0.0187 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9853; time: 000:06:54
# epoch 76/80...  train/loss: 0.0187 val/loss: 0.0123 lr: 0.000125 metric/SSIM: 0.9859; time: 000:06:17
# epoch 77/80...  train/loss: 0.0187 val/loss: 0.0124 lr: 0.000125 metric/SSIM: 0.9856; time: 000:06:21
# epoch 78/80...  train/loss: 0.0187 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9853; time: 000:06:17
# epoch 79/80...  train/loss: 0.0186 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9854; time: 000:06:29
# epoch 80/80...  train/loss: 0.0187 val/loss: 0.0125 lr: 0.000125 metric/SSIM: 0.9854; time: 000:06:26

# %%
trainer.history.plot()

# %%
trainer.history.plot(train=False, val=False, metric='SSIM')

# %%
def plot_results(img_lr, img_reconstructed, img_gt):
    img_lr_resized = kornia.geometry.resize(img_lr, (img_reconstructed.shape[1],
                                                     img_reconstructed.shape[2]), interpolation='bicubic', antialias=True)
    ssim_lr = kornia.metrics.ssim(img1=img_lr_resized[None,:], img2=img_gt[None,:], window_size=11).mean()
    ssim_reconstructed = kornia.metrics.ssim(img_reconstructed[None,:], img_gt[None,:], window_size=11).mean()
    plt.subplots(1,3, figsize=(15,10))
    plt.subplot(1,3,1)
    plt.imshow(img_gt.permute(1,2,0))
    plt.title(f'hr ground true')
    plt.subplot(1,3,2)
    plt.imshow(img_lr_resized.permute(1,2,0))
    plt.title(f'bicubic, SSIM={ssim_lr:.4f}')
    plt.subplot(1,3,3)
    plt.imshow(img_reconstructed.permute(1,2,0))
    plt.title(f'reconstructed, SSIM={ssim_reconstructed:.4f}')

# %%
torch.save(model.state_dict(), 'cnn_256_11blocks_128_80ep_08ssim_01l2_01tv_noise002.pt')

# %%
#model = sr_from_lr(scale=2, n_blocks=5, channels=128).to(device)
#model.load_state_dict(torch.load('cnn_256_11blocks_128_20ep_08ssim_01l2_01tv_pyrdown.pt'))
#model.eval()
#print(model)

# %%
n = 55
torch.cuda.empty_cache()
device_ = 'cuda'
img_lr = ds_train_patches.dataset.images_source_patches[n]
img_ref = ds_train_patches.dataset.images_ref_patches[n]
model.eval()
with torch.no_grad():
    model = model.to(device_)
    img_reconstructed = model(img_lr[None,:].to(device_))[0].detach().cpu()
plot_results(img_lr, img_reconstructed, img_ref)
torchvision.utils.save_image(img_lr, 'v3_in.png')
torchvision.utils.save_image(img_reconstructed, 'v3_out.png')
torchvision.utils.save_image(img_ref, 'v3_ref.png')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
n = 300
torch.cuda.empty_cache()
device_ = 'cuda'
img_lr = ds_train_patches.dataset.images_source_img[n]
img_ref = ds_train_patches.dataset.images_ref_img[n]
model.eval()
with torch.no_grad():
    model = model.to(device_)
    img_reconstructed = model(img_lr[None,:].to(device_))[0].detach().cpu()
plot_results(img_lr, img_reconstructed, img_ref)
torchvision.utils.save_image(img_lr, 'v3_full_in.png')
torchvision.utils.save_image(img_reconstructed, 'v3_full_out.png')
torchvision.utils.save_image(img_ref, 'v3_full_ref.png')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
ds_set5 = data.data_set5_x2()
ds_urban100 = data.data_urban100_x2()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 60.24it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 53.77it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 41.95it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:05<00:00, 18.80it/s]

# %%
n = 2
torch.cuda.empty_cache()
device_ = 'cuda'
img_lr = ds_set5.images_source_img[n]
img_ref = ds_set5.images_ref_img[n]
model.eval()
with torch.no_grad():
    model = model.to(device_)
    img_reconstructed = model(img_lr[None,:].to(device_))[0].detach().cpu()
plot_results(img_lr, img_reconstructed, img_ref)
torchvision.utils.save_image(img_lr, 'v3_set5_in.png')
torchvision.utils.save_image(img_reconstructed, 'v3_set5_out.png')
torchvision.utils.save_image(img_ref, 'v3_set_ref.png')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
n = 39 #62
torch.cuda.empty_cache()
device_ = 'cuda'
img_lr = ds_urban100.images_source_img[n]
img_ref = ds_urban100.images_ref_img[n]
model.eval()
with torch.no_grad():
    model = model.to(device_)
    img_reconstructed = model(img_lr[None,:].to(device_))[0].detach().cpu()
plot_results(img_lr, img_reconstructed, img_ref)
torchvision.utils.save_image(img_lr, 'v3_urban100_in.png')
torchvision.utils.save_image(img_reconstructed, 'v3_urban100_out.png')
torchvision.utils.save_image(img_ref, 'v3_urban100_ref.png')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def calc_mean_results(ds, model, device):
    results = []
    model.eval()
    with torch.no_grad():
        for i in range(ds.__len__()):
            torch.cuda.empty_cache()
            img_lr = ds.images_source_img[i].to(device)
            img_gt = ds.images_ref_img[i].to(device)
            img_reconstructed = model(img_lr[None,:])
            img_lr_resized = kornia.geometry.resize(img_lr, (img_reconstructed.shape[2],
                                                             img_reconstructed.shape[3]), interpolation='bicubic', antialias=True)
            del img_lr
            if img_reconstructed[0].size()==img_gt.size():
                ssim_lr = kornia.metrics.ssim(img1=img_lr_resized[None,:], img2=img_gt[None,:], window_size=11).mean()
                ssim_reconstructed = kornia.metrics.ssim(img_reconstructed, img_gt[None,:], window_size=11).mean()
                del img_reconstructed
                del img_lr_resized
                results.append([ssim_lr, ssim_reconstructed])
        results = torch.tensor(results)
        results_mean = results.mean(dim=0)
    return results_mean, results

# %%
res = calc_mean_results(ds_urban100, model, device)
res
# Out:
# (tensor([0.8234, 0.8281]),
#  tensor([[0.8107, 0.8171],
#          [0.8611, 0.8663],
#          [0.9412, 0.9406],
#          [0.7147, 0.7028],
#          [0.7971, 0.7923],
#          [0.8512, 0.8525],
#          [0.7409, 0.7671],
#          [0.9139, 0.9187],
#          [0.8190, 0.8089],
#          [0.8660, 0.8656],
#          [0.9321, 0.9293],
#          [0.7510, 0.7639],
#          [0.6911, 0.7039],
#          [0.9027, 0.9120],
#          [0.8503, 0.8518],
#          [0.9127, 0.9174],
#          [0.9044, 0.8989],
#          [0.7395, 0.7351],
#          [0.7654, 0.7793],
#          [0.8744, 0.9224],
#          [0.8090, 0.8156],
#          [0.8435, 0.8477],
#          [0.8272, 0.8194],
#          [0.8145, 0.8211],
#          [0.7432, 0.7612],
#          [0.9177, 0.9277],
#          [0.8385, 0.8444],
#          [0.9038, 0.8942],
#          [0.6826, 0.6847],
#          [0.8529, 0.8604],
#          [0.6450, 0.6358],
#          [0.7628, 0.7738],
#          [0.8806, 0.8975],
#          [0.9173, 0.9053],
#          [0.7476, 0.7521],
#          [0.8690, 0.8663],
#          [0.7707, 0.7773],
#          [0.8551, 0.8533],
#          [0.7812, 0.7928],
#          [0.9556, 0.9329],
#          [0.9439, 0.9417],
#          [0.8726, 0.8664],
#          [0.9409, 0.9419],
#          [0.9289, 0.9308],
#          [0.8719, 0.8863],
#          [0.7157, 0.7266],
#          [0.8299, 0.8312],
#          [0.6546, 0.6895],
#          [0.9319, 0.9301],
#          [0.8330, 0.8414],
#          [0.6124, 0.6361],
#          [0.8653, 0.8786],
#          [0.6651, 0.6765],
#          [0.7389, 0.7294]]))

# %%
res = calc_mean_results(ds_set5, model, device)
res
# Out:
# (tensor([0.9125, 0.9074]),
#  tensor([[0.9463, 0.9355],
#          [0.9657, 0.9496],
#          [0.9022, 0.9192],
#          [0.8035, 0.7970],
#          [0.9448, 0.9358]]))

# %%
ds_div2k = data.data_patches_div2k_bicubic_x2_train()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:39<00:00, 20.10it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 800/800 [00:29<00:00, 27.00it/s]
#  98%|██████████████████████████████████████████████████████████████████████████████▌ | 786/800 [00:31<00:00, 25.26it/s]

# %%
res = calc_mean_results(ds_div2k, model, device)
res
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14704\2887414618.py in <module>
# ----> 1 res = calc_mean_results(ds_div2k, model, device)
#       2 res
#
# ~\AppData\Local\Temp\ipykernel_14704\4011861994.py in calc_mean_results(ds, model, device)
#       5         for i in range(ds.__len__()):
#       6             torch.cuda.empty_cache()
# ----> 7             img_lr = ds.images_source_img[i].to(device)
#       8             img_gt = ds.images_ref_img[i].to(device)
#       9             img_reconstructed = model(img_lr[None,:])
#
# C:\anaconda3\lib\site-packages\torchvision\tv_tensors\_tv_tensor.py in __torch_function__(cls, func, types, args, kwargs)
#      75         # DisableTorchFunctionSubclass and then manually re-wrap the output if necessary
#      76         with DisableTorchFunctionSubclass():
# ---> 77             output = func(*args, **kwargs or dict())
#      78
#      79         must_return_subclass = _must_return_subclass()
#
# KeyboardInterrupt:

# %%
res
# Out:
# (tensor(nan), tensor([]))
